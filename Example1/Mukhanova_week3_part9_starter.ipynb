# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### загружаем датафрейм

# %%
states_df = pd.read_excel('states.xlsx')
states_sr = pd.read_excel('states.xlsx', usecols=["State"]).squeeze()
states_df
# Out:
#    Abbreviation           State    Capital City  pop_rank       Pop  Growth  \
# 0            AL         Alabama      Montgomery        24   5073187  0.0048
# 1            AK          Alaska          Juneau        48    738023  0.0031
# 2            AZ         Arizona         Phoenix        14   7303398  0.0105
# 3            AR        Arkansas     Little Rock        33   3030646  0.0032
# 4            CA      California      Sacramento         1  39995077  0.0057
# 5            CO        Colorado          Denver        21   5922618  0.0127
# 6            CT     Connecticut        Hartford        29   3612314  0.0009
# 7            DE        Delaware           Dover        45   1008350  0.0092
# 8            FL         Florida     Tallahassee         3  22085563  0.0125
# 9            GA         Georgia         Atlanta         8  10916760  0.0095
# 10           HI          Hawaii        Honolulu        40   1474265  0.0065
# ...

# %% [markdown]
# ### атрибуты, применимые и для series, и для dataframes

# %%
# атрибут .index для series
states_sr.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# атрибут .index для dataframe
states_df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# атрибут .values для series
states_sr.values
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
# атрибут .values для dataframe
states_df.values
# Out:
# array([['AL', 'Alabama', 'Montgomery', 24, 5073187, 0.0048, 5048733,
#         4779736, 0.0614, 0.0151, 100.1715],
#        ['AK', 'Alaska', 'Juneau', 48, 738023, 0.0031, 735707, 710231,
#         0.0391, 0.0022, 1.2933],
#        ['AZ', 'Arizona', 'Phoenix', 14, 7303398, 0.0105, 7227450,
#         6392017, 0.1426, 0.0218, 64.2939],
#        ['AR', 'Arkansas', 'Little Rock', 33, 3030646, 0.0032, 3021085,
#         2915918, 0.0393, 0.009, 58.2425],
#        ['CA', 'California', 'Sacramento', 1, 39995077, 0.0057, 39766650,
#         37253956, 0.0736, 0.1193, 256.7424],
#        ['CO', 'Colorado', 'Denver', 21, 5922618, 0.0127, 5848166,
#         5029196, 0.1776, 0.0177, 57.145],
#        ['CT', 'Connecticut', 'Hartford', 29, 3612314, 0.0009, 3609129,
#         3574097, 0.0107, 0.0108, 746.0376],
#        ['DE', 'Delaware', 'Dover', 45, 1008350, 0.0092, 999149, 897934,
#         0.123, 0.003, 517.3679],
#        ['FL', 'Florida', 'Tallahassee', 3, 22085563, 0.0125, 21811875,
# ...

# %%
# атрибут .shape для series
states_sr.shape
# Out:
# (50,)

# %%
# атрибут .shape для dataframe
states_df.shape
# Out:
# (50, 11)

# %%
# атрибут .dtype для series
states_sr.dtype
# Out:
# dtype('O')

# %%
# атрибут .dtypeS (!) для dataframe
states_df.dtypes
# Out:
# Abbreviation        object
# State               object
# Capital City        object
# pop_rank             int64
# Pop                  int64
# Growth             float64
# Pop2021              int64
# Pop2010              int64
# growthSince2010    float64
# Percent            float64
# density            float64
# dtype: object

# %%
# атрибут .dtypes вместе value_counts() для dataframe - сколько колонок с какими типами данных
states_df.dtypes.value_counts()
# Out:
# int64      4
# float64    4
# object     3
# Name: count, dtype: int64

# %%
# атрибут .axes для series покажет то же, как .index
states_sr.axes
# Out:
# [RangeIndex(start=0, stop=50, step=1)]

# %%
# атрибут .axes для dataframe
states_df.axes
# Out:
# [RangeIndex(start=0, stop=50, step=1),
#  Index(['Abbreviation', 'State', 'Capital City', 'pop_rank', 'Pop', 'Growth',
#         'Pop2021', 'Pop2010', 'growthSince2010', 'Percent', 'density'],
#        dtype='object')]

# %% [markdown]
# ### атрибуты, применимые только для dataframes

# %%
# атрибут .column для series - НЕ существует
states_sr.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24380\3616347999.py in ?()
#       1 # атрибут .column для series - НЕ существует
# ----> 2 states_sr.column
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'column'

# %%
# атрибут .columnS для dataframe
states_df.columns
# Out:
# Index(['Abbreviation', 'State', 'Capital City', 'pop_rank', 'Pop', 'Growth',
#        'Pop2021', 'Pop2010', 'growthSince2010', 'Percent', 'density'],
#       dtype='object')

# %% [markdown]
# ### методы, применимые и для series, и для dataframes

# %%
# методы head() и tail() для series
states_sr.head()
# Out:
# 45         Virginia
# 46       Washington
# 47    West Virginia
# 48        Wisconsin
# 49          Wyoming
# Name: State, dtype: object

# %%
# методы head() и tail() для dataframe
states_df.tail()
# Out:
#    Abbreviation          State Capital City  pop_rank      Pop  Growth  \
# 45           VA       Virginia     Richmond        12  8757467  0.0073
# 46           WA     Washington      Olympia        13  7901429  0.0126
# 47           WV  West Virginia   Charleston        39  1781860 -0.0033
# 48           WI      Wisconsin      Madison        20  5935064  0.0035
# 49           WY        Wyoming     Cheyenne        50   579495  0.0023
#
#     Pop2021  Pop2010  growthSince2010  Percent   density
# 45  8694430  8001024           0.0945   0.0261  221.7642
# 46  7803355  6724540           0.1750   0.0236  118.8971
# 47  1787788  1852994          -0.0384   0.0053   74.1268
# 48  5914391  5686986           0.0436   0.0177  109.5879
# 49   578173   563626           0.0282   0.0017    5.9685

# %%
# метод info() для series
states_sr.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50 entries, 0 to 49
# Series name: State
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     object
# dtypes: object(1)
# memory usage: 532.0+ bytes

# %%
# метод info() для dataframe
states_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Abbreviation     50 non-null     object
#  1   State            50 non-null     object
#  2   Capital City     50 non-null     object
#  3   pop_rank         50 non-null     int64
#  4   Pop              50 non-null     int64
#  5   Growth           50 non-null     float64
#  6   Pop2021          50 non-null     int64
#  7   Pop2010          50 non-null     int64
#  8   growthSince2010  50 non-null     float64
#  9   Percent          50 non-null     float64
#  10  density          50 non-null     float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 4.4+ KB

# %%
# метод .describe() для series, тип данных текст
states_sr.describe()
# Out:
# count          50
# unique         50
# top       Alabama
# freq            1
# Name: State, dtype: object

# %%
# метод .describe() для series, тип данных числовой
states_sr_num = pd.read_excel('states.xlsx', usecols=["density"]).squeeze()

states_sr_num.describe()
# Out:
# count      50.000000
# mean      208.861176
# std       277.731890
# min         1.293300
# 25%        48.028675
# 50%       108.986050
# 75%       227.587800
# max      1276.640500
# Name: density, dtype: float64

# %%
# метод .describe() для dataframe
states_df.describe()
# Out:
#        pop_rank           Pop     Growth       Pop2021       Pop2010  \
# count  50.00000  5.000000e+01  50.000000  5.000000e+01  5.000000e+01
# mean   25.50000  6.705658e+06   0.006164  6.660427e+06  6.162876e+06
# std    14.57738  7.556714e+06   0.004283  7.496315e+06  6.848235e+06
# min     1.00000  5.794950e+05  -0.003300  5.781730e+05  5.636260e+05
# 25%    13.25000  1.917192e+06   0.002750  1.893448e+06  1.833004e+06
# 50%    25.50000  4.610882e+06   0.005250  4.596339e+06  4.436370e+06
# 75%    37.75000  7.751921e+06   0.009075  7.659379e+06  6.680312e+06
# max    50.00000  3.999508e+07   0.015300  3.976665e+07  3.725396e+07
#
#        growthSince2010    Percent      density
# count        50.000000  50.000000    50.000000
# mean          0.082392   0.020002   208.861176
# std           0.060781   0.022541   277.731890
# min          -0.038400   0.001700     1.293300
# 25%           0.034425   0.005675    48.028675
# 50%           0.067150   0.013750   108.986050
# ...

# %%
# метод .Series() (!) S с большой буквы
mylist = ["data", "boom", "python", "course", "is", "my", "favorite"]
mySeries=pd.Series(mylist)
mySeries
# Out:
# 0        data
# 1        boom
# 2      python
# 3      course
# 4          is
# 5          my
# 6    favorite
# dtype: object

# %%
# метод .DataFrame() (!) D и F с большой буквы
mylist2 = [[1,"data"], [2,"boom"], [3,"python"]]
MyDataFrame = pd.DataFrame(mylist2, columns = ["nums", "word"])
MyDataFrame
# Out:
#    nums    word
# 0     1    data
# 1     2    boom
# 2     3  python

# %% [markdown]
# ### работа с одной колонкой в dataframes

# %%
# dataframe.columnname - возвращает конкретную колонку, чувствительный к регистру
# НЕ работает, если в названии колонки есть пробелы
states_df.State.head()
# Out:
# 0       Alabama
# 1        Alaska
# 2       Arizona
# 3      Arkansas
# 4    California
# Name: State, dtype: object

# %%
# dataframe.columnname - возвращает конкретную колонку, чувствительный к регистру
# работает, если в названии колонки есть пробелы
states_df["State"].head()
# Out:
# 0       Alabama
# 1        Alaska
# 2       Arizona
# 3      Arkansas
# 4    California
# Name: State, dtype: object

# %% [markdown]
# ### работа с двумя и более колонками в dataframes

# %%
#нужны двойные квадратные скобки ([лист] с названиями колонок внутри [])
states_df[["State","Pop"]].head()
# Out:
#         State       Pop
# 0     Alabama   5073187
# 1      Alaska    738023
# 2     Arizona   7303398
# 3    Arkansas   3030646
# 4  California  39995077

# %%
#колонки вернутся в том порядке, который вы указали
states_df[["Pop","State"]].head()
# Out:
#         Pop       State
# 0   5073187     Alabama
# 1    738023      Alaska
# 2   7303398     Arizona
# 3   3030646    Arkansas
# 4  39995077  California

# %%
#лучшая практика (best practice) - список колонок сохранить в отдельную переменную (лист)
columns = ["State","Pop","density"]
states_df[columns].head()
# Out:
#         State       Pop   density
# 0     Alabama   5073187  100.1715
# 1      Alaska    738023    1.2933
# 2     Arizona   7303398   64.2939
# 3    Arkansas   3030646   58.2425
# 4  California  39995077  256.7424

# %% [markdown]
# ### добавляем колонки в dataframe

# %%
states_df.head()
# Out:
#   Abbreviation       State Capital City  pop_rank       Pop  Growth   Pop2021  \
# 0           AL     Alabama   Montgomery        24   5073187  0.0048   5048733
# 1           AK      Alaska       Juneau        48    738023  0.0031    735707
# 2           AZ     Arizona      Phoenix        14   7303398  0.0105   7227450
# 3           AR    Arkansas  Little Rock        33   3030646  0.0032   3021085
# 4           CA  California   Sacramento         1  39995077  0.0057  39766650
#
#     Pop2010  growthSince2010  Percent   density
# 0   4779736           0.0614   0.0151  100.1715
# 1    710231           0.0391   0.0022    1.2933
# 2   6392017           0.1426   0.0218   64.2939
# 3   2915918           0.0393   0.0090   58.2425
# 4  37253956           0.0736   0.1193  256.7424

# %%
#добавить колонку в датафрейм
states_df["new"] = "default_value"

# %%
states_df.head()
# Out:
#   Abbreviation       State Capital City  pop_rank       Pop  Growth   Pop2021  \
# 0           AL     Alabama   Montgomery        24   5073187  0.0048   5048733
# 1           AK      Alaska       Juneau        48    738023  0.0031    735707
# 2           AZ     Arizona      Phoenix        14   7303398  0.0105   7227450
# 3           AR    Arkansas  Little Rock        33   3030646  0.0032   3021085
# 4           CA  California   Sacramento         1  39995077  0.0057  39766650
#
#     Pop2010  growthSince2010  Percent   density            new
# 0   4779736           0.0614   0.0151  100.1715  default_value
# 1    710231           0.0391   0.0022    1.2933  default_value
# 2   6392017           0.1426   0.0218   64.2939  default_value
# 3   2915918           0.0393   0.0090   58.2425  default_value
# 4  37253956           0.0736   0.1193  256.7424  default_value

# %%
# метод .insert() чтобы добавить колонку в определенное место с помощью индекса
states_df.insert(0, column = "new1", value = "1111")

# %%
states_df.head()
# Out:
#    new1 Abbreviation       State Capital City  pop_rank     Pop  Growth  \
# 0  1111           AL     Alabama   Montgomery        24   50731  0.0048
# 1  1111           AK      Alaska       Juneau        48    7380  0.0031
# 2  1111           AZ     Arizona      Phoenix        14   73033  0.0105
# 3  1111           AR    Arkansas  Little Rock        33   30306  0.0032
# 4  1111           CA  California   Sacramento         1  399950  0.0057
#
#     Pop2021   Pop2010  growthSince2010  Percent   density            new
# 0   5048733   4779736           0.0614   0.0151  100.1715  default_value
# 1    735707    710231           0.0391   0.0022    1.2933  default_value
# 2   7227450   6392017           0.1426   0.0218   64.2939  default_value
# 3   3021085   2915918           0.0393   0.0090   58.2425  default_value
# 4  39766650  37253956           0.0736   0.1193  256.7424  default_value

# %%
#изменить колонку, не меняя сам датафрейм
states_df["Pop"].div(1000).head()
# Out:
# 0     507.318
# 1      73.802
# 2     730.339
# 3     303.064
# 4    3999.507
# Name: Pop, dtype: float64

# %%
#изменить (перезаписать) колонку в датафрейм
states_df["Pop"] = states_df["Pop"].floordiv(10)

# %%
states_df.head()
# Out:
#    new1 Abbreviation       State Capital City  pop_rank     Pop  Growth  \
# 0  1111           AL     Alabama   Montgomery        24   50731  0.0048
# 1  1111           AK      Alaska       Juneau        48    7380  0.0031
# 2  1111           AZ     Arizona      Phoenix        14   73033  0.0105
# 3  1111           AR    Arkansas  Little Rock        33   30306  0.0032
# 4  1111           CA  California   Sacramento         1  399950  0.0057
#
#     Pop2021   Pop2010  growthSince2010  Percent   density            new
# 0   5048733   4779736           0.0614   0.0151  100.1715  default_value
# 1    735707    710231           0.0391   0.0022    1.2933  default_value
# 2   7227450   6392017           0.1426   0.0218   64.2939  default_value
# 3   3021085   2915918           0.0393   0.0090   58.2425  default_value
# 4  39766650  37253956           0.0736   0.1193  256.7424  default_value

# %%
#перезаписываем датафрейм
states_df = pd.read_excel('states.xlsx')

# %%
states_df.head()
# Out:
#   Abbreviation       State Capital City  pop_rank       Pop  Growth   Pop2021  \
# 0           AL     Alabama   Montgomery        24   5073187  0.0048   5048733
# 1           AK      Alaska       Juneau        48    738023  0.0031    735707
# 2           AZ     Arizona      Phoenix        14   7303398  0.0105   7227450
# 3           AR    Arkansas  Little Rock        33   3030646  0.0032   3021085
# 4           CA  California   Sacramento         1  39995077  0.0057  39766650
#
#     Pop2010  growthSince2010  Percent   density
# 0   4779736           0.0614   0.0151  100.1715
# 1    710231           0.0391   0.0022    1.2933
# 2   6392017           0.1426   0.0218   64.2939
# 3   2915918           0.0393   0.0090   58.2425
# 4  37253956           0.0736   0.1193  256.7424

# %% [markdown]
# ### метод `value_counts()` - подсчет кол-ва одинаковых значений (частоты)

# %%
#загружаем данные, students performance
st_df = pd.read_csv('studentsperformance.csv')
st_sr = pd.read_csv('studentsperformance.csv',usecols=['race/ethnicity']).squeeze()
st_df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# метод value_counts() для series
st_sr.value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
# метод value_counts() для dataframe
st_df['math score'].value_counts()
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64
