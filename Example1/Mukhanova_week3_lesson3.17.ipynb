# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### загружаем датафрейм

# %%
#загружаем данные, students performance
st_df = pd.read_excel('studentsperformance7.xlsx')
st_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E                         NaN      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998     NaN            NaN                         NaN           NaN
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed        88.0           99.0           95.0
# 996                     NaN        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
# 998                     NaN         NaN            NaN            NaN
# 999                    none        77.0           86.0           86.0
#
#      speaking score
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 995             NaN
# 996             NaN
# 997             NaN
# 998             NaN
# 999             NaN
#
# [1000 rows x 9 columns]

# %%
#метод .info() - типы данных и сколько памяти занимает наш датасет
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    object
#  1   race/ethnicity               985 non-null    object
#  2   parental level of education  955 non-null    object
#  3   lunch                        967 non-null    object
#  4   test preparation course      956 non-null    object
#  5   math score                   995 non-null    float64
#  6   reading score                995 non-null    float64
#  7   writing score                995 non-null    float64
#  8   speaking score               0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 70.4+ KB

# %%
#атрибут .dtypes
st_df.dtypes
# Out:
# gender                         category
# race/ethnicity                 category
# parental level of education    category
# lunch                          category
# test preparation course        category
# math score                        int32
# reading score                     int32
# writing score                     int32
# speaking score                  float64
# math rank                         int32
# dtype: object

# %% [markdown]
# ###  `.astype()`  метод чтобы поменять тип данных

# %%
#метод .astype() - не сработает если есть Nulls
st_df["math score"] = st_df["math score"].astype("int")
st_df["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 994    63
# 995    88
# 996    62
# 997    59
# 999    77
# Name: math score, Length: 995, dtype: int32

# %%
#метод .dropna() чтобы удалить Nulls, обязательно указать параметр inplace=True 
#чтобы изменение было перманентным, то есть чтобы на самом деле удалить в исходном датасете
st_df.dropna(how = "all", inplace = True)

# %%
#удалили Nulls, пробуем снова - сработало!
st_df["math score"] = st_df["math score"].astype("int")
st_df["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 994    63
# 995    88
# 996    62
# 997    59
# 999    77
# Name: math score, Length: 995, dtype: int32

# %% [markdown]
# ###  методы `unique` и `nunique()`

# %%
#.nunique() - кол-во уникальных значений в колонке без учета NaN - по умолчанию
st_df["race/ethnicity"].nunique()
# Out:
# 5

# %%
#.unique() - список уникальных значений в колонке 
st_df["race/ethnicity"].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E', nan],
#       dtype=object)

# %%
#.nunique() - кол-во уникальных значений в колонке, параметр dropna=False - с учетом NaN 
st_df["race/ethnicity"].nunique(dropna=False)
# Out:
# 6

# %% [markdown]
# ###  категории в Pandas

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    object
#  1   race/ethnicity               985 non-null    object
#  2   parental level of education  955 non-null    object
#  3   lunch                        967 non-null    object
#  4   test preparation course      956 non-null    category
#  5   math score                   995 non-null    int32
#  6   reading score                995 non-null    int32
#  7   writing score                995 non-null    int32
#  8   speaking score               0 non-null      float64
# dtypes: category(1), float64(1), int32(3), object(4)
# memory usage: 59.4+ KB

# %%
#"reading score", "writing score","speaking score"
# st_df["math score"] = st_df["math score"].astype("int")
# st_df["math score"]
#st_df["reading score"] = st_df["reading score"].astype("int")
#st_df["reading score"]
st_df["writing score"] = st_df["writing score"].astype("int")
st_df["writing score"]
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 994    62
# 995    95
# 996    55
# 997    65
# 999    86
# Name: writing score, Length: 995, dtype: int32

# %%
columns = ["speaking score"]
st_df.dropna(subset=columns).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       0 non-null      object
#  1   race/ethnicity               0 non-null      object
#  2   parental level of education  0 non-null      object
#  3   lunch                        0 non-null      object
#  4   test preparation course      0 non-null      category
#  5   math score                   0 non-null      int32
#  6   reading score                0 non-null      int32
#  7   writing score                0 non-null      int32
#  8   speaking score               0 non-null      float64
# dtypes: category(1), float64(1), int32(3), object(4)
# memory usage: 124.0+ bytes

# %%
st_df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       0 non-null      object
#  1   race/ethnicity               0 non-null      object
#  2   parental level of education  0 non-null      object
#  3   lunch                        0 non-null      object
#  4   test preparation course      0 non-null      category
#  5   math score                   0 non-null      int32
#  6   reading score                0 non-null      int32
#  7   writing score                0 non-null      int32
#  8   speaking score               0 non-null      float64
# dtypes: category(1), float64(1), int32(3), object(4)
# memory usage: 124.0+ bytes

# %%
st_df.dropna(how="all").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    object
#  1   race/ethnicity               985 non-null    object
#  2   parental level of education  955 non-null    object
#  3   lunch                        967 non-null    object
#  4   test preparation course      956 non-null    category
#  5   math score                   995 non-null    int32
#  6   reading score                995 non-null    int32
#  7   writing score                995 non-null    int32
#  8   speaking score               0 non-null      float64
# dtypes: category(1), float64(1), int32(3), object(4)
# memory usage: 59.4+ KB

# %%
columns = ["speaking score"]
st_df.dropna(subset=columns).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       0 non-null      category
#  1   race/ethnicity               0 non-null      category
#  2   parental level of education  0 non-null      category
#  3   lunch                        0 non-null      category
#  4   test preparation course      0 non-null      category
#  5   math score                   0 non-null      int32
#  6   reading score                0 non-null      int32
#  7   writing score                0 non-null      int32
#  8   speaking score               0 non-null      float64
# dtypes: category(5), float64(1), int32(3)
# memory usage: 804.0 bytes

# %%
st_df["speaking score"] = st_df["speaking score"].astype("int")
st_df["speaking score"]
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 st_df["speaking score"] = st_df["speaking score"].astype("int")
#       2 st_df["speaking score"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:146, in _astype_float_to_int_nansafe(values, dtype, copy)
#     142 """
#     143 astype with a check preventing converting NaN to an meaningless integer value.
#     144 """
#     145 if not np.isfinite(values).all():
# --> 146     raise IntCastingNaNError(
#     147         "Cannot convert non-finite values (NA or inf) to integer"
#     148     )
#     149 if dtype.kind == "u":
#     150     # GH#45151
#     151     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
#Если есть категориальные данные (пол, раса, уровень образования и тп), 
# mо категории могут сэкономить память

# .astype("category") конвертируем в категорию
# st_df["race/ethnicity"] = st_df["race/ethnicity"].astype("category")
# st_df["gender"] = st_df["gender"].astype("category")
# st_df["parental level of education"] = st_df["parental level of education"].astype("category")
# st_df["lunch"] = st_df["lunch"].astype("category")
st_df["test preparation course"] = st_df["test preparation course"].astype("category")

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    category
#  1   race/ethnicity               985 non-null    category
#  2   parental level of education  955 non-null    category
#  3   lunch                        967 non-null    category
#  4   test preparation course      956 non-null    category
#  5   math score                   995 non-null    int32
#  6   reading score                995 non-null    int32
#  7   writing score                995 non-null    int32
#  8   speaking score               0 non-null      float64
# dtypes: category(5), float64(1), int32(3)
# memory usage: 32.9 KB

# %% [markdown]
# ### `.sort_values()` сортируем по значениям

# %%
st_df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
# 5                    none          71           83.0           78.0
# 6               completed          88           95.0           92.0
# 7                    none          40           43.0           39.0
# 8               completed          64           64.0           67.0
# 9                    none          38           60.0           50.0
#
#    speaking score
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN

# %%
# .sort_values() сортирует по колонке
st_df.sort_values("race/ethnicity")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 395    male        group A                 high school  free/reduced
# 490  female        group A          associate's degree  free/reduced
# 546  female        group A            some high school      standard
# 778  female        group A                some college      standard
# 384  female        group A            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 217  female            NaN                 high school  free/reduced
# 218    male            NaN                 high school  free/reduced
# 219    male            NaN            some high school      standard
# 220  female            NaN                 high school      standard
# 994    male            NaN                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 395                    none          48           45.0           41.0
# 490                    none          65           85.0           76.0
# 546               completed          92          100.0           97.0
# 778               completed          72           79.0           82.0
# 384                    none          38           43.0           43.0
# ..                      ...         ...            ...            ...
# 217                    none          34           42.0           39.0
# 218                    none          66           77.0           70.0
# 219               completed          61           56.0           56.0
# 220               completed          56           68.0           74.0
# 994                    none          63           63.0           62.0
#
#      speaking score
# 395             NaN
# 490             NaN
# 546             NaN
# 778             NaN
# 384             NaN
# ..              ...
# 217             NaN
# 218             NaN
# 219             NaN
# 220             NaN
# 994             NaN
#
# [995 rows x 9 columns]

# %%
#.sort_values() сортирует по колонке, параметр ascending=False чтобы по убыванию
st_df.sort_values("math score", ascending = False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17      NaN        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100           92.0           97.0
# 625               completed         100           97.0           99.0
# 916               completed         100          100.0          100.0
# 149                     NaN         100          100.0           93.0
# 623               completed         100           96.0           86.0
# ..                      ...         ...            ...            ...
# 145                     NaN          22           39.0           33.0
# 787                    none          19           38.0           32.0
# 17                     none          18           32.0           28.0
# 980                    none           8           24.0           23.0
# 59                     none           0           17.0           10.0
#
#      speaking score
# 451             NaN
# 625             NaN
# 916             NaN
# 149             NaN
# 623             NaN
# ..              ...
# 145             NaN
# 787             NaN
# 17              NaN
# 980             NaN
# 59              NaN
#
# [995 rows x 9 columns]

# %%
# NaN по умолчанию в конце, параметр na_position = "first" чтобы NaN попали в начало
# st_df.sort_values("race/ethnicity")
st_df.sort_values("race/ethnicity", ascending=False)
st_df.sort_values("race/ethnicity", ascending=False, na_position = "first")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 212  female            NaN                 high school  free/reduced
# 213    male            NaN          associate's degree  free/reduced
# 214    male            NaN                 high school      standard
# 215    male            NaN            some high school      standard
# 216  female            NaN          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 830  female        group A                some college  free/reduced
# 296    male        group A            some high school      standard
# 300    male        group A                some college  free/reduced
# 832    male        group A           bachelor's degree      standard
# 365    male        group A           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 212                    none          42           62.0           60.0
# 213               completed          60           51.0           56.0
# 214               completed          87           91.0           81.0
# 215               completed          84           83.0           75.0
# 216               completed          83           86.0           88.0
# ..                      ...         ...            ...            ...
# 830                    none          61           60.0           57.0
# 296               completed          46           41.0           43.0
# 300               completed          81           78.0           81.0
# 832                    none          64           60.0           58.0
# 365                     NaN          49           58.0           60.0
#
#      speaking score
# 212             NaN
# 213             NaN
# 214             NaN
# 215             NaN
# 216             NaN
# ..              ...
# 830             NaN
# 296             NaN
# 300             NaN
# 832             NaN
# 365             NaN
#
# [995 rows x 9 columns]

# %%
# сортируем по 3 колонкам
st_df.sort_values(["race/ethnicity","parental level of education","math score"], ascending=False).head(30)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 171    male        group E            some high school      standard
# 233    male        group E            some high school      standard
# 793    male        group E            some high school      standard
# 813    male        group E            some high school      standard
# 853    male        group E            some high school      standard
# 987    male        group E            some high school      standard
# 711  female        group E            some high school      standard
# 545    male        group E            some high school  free/reduced
# 289    male        group E            some high school      standard
# 581  female        group E            some high school      standard
# 925    male        group E            some high school      standard
# 952  female        group E            some high school  free/reduced
# 390    male        group E            some high school  free/reduced
# 786  female        group E            some high school  free/reduced
# 727    male        group E            some high school      standard
# 383  female        group E            some high school  free/reduced
# 895  female        group E            some high school  free/reduced
# 76     male        group E            some high school      standard
# 306    male        group E                some college      standard
# 34     male        group E                some college      standard
# 689    male        group E                some college  free/reduced
# 132    male        group E                some college  free/reduced
# 852  female        group E                some college      standard
# 638    male        group E                some college      standard
# 890  female        group E                some college      standard
# 686    male        group E                some college      standard
# 370    male        group E                some college      standard
# 411    male        group E                some college      standard
# 124    male        group E                some college      standard
# 725    male        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 171                    none          94           88.0           78.0
# 233                    none          92           87.0           78.0
# 793               completed          89           84.0           77.0
# 813               completed          87           84.0           76.0
# 853                    none          82           67.0           61.0
# 987               completed          81           75.0           76.0
# 711               completed          80           85.0           85.0
# 545               completed          78           83.0           80.0
# 289               completed          77           76.0           77.0
# 581                    none          77           79.0           80.0
# 925               completed          74           64.0           60.0
# 952                    none          74           74.0           72.0
# 390               completed          73           67.0           59.0
# 786                    none          72           79.0           77.0
# 727               completed          68           51.0           57.0
# 383                    none          38           49.0           45.0
# 895                    none          32           34.0           38.0
# 76                     none          30           26.0           22.0
# 306               completed          99           87.0           81.0
# 34                     none          97           87.0           82.0
# 689                    none          93           90.0           83.0
# 132               completed          87           74.0           70.0
# 852                    none          87           85.0           93.0
# 638                    none          86           76.0           74.0
# 890               completed          86           85.0           91.0
# 686               completed          85           75.0           68.0
# 370                    none          84           77.0           71.0
# 411               completed          84           83.0           78.0
# 124                    none          83           80.0           73.0
# 725               completed          81           74.0           71.0
#
#      speaking score
# 171             NaN
# 233             NaN
# 793             NaN
# 813             NaN
# 853             NaN
# 987             NaN
# 711             NaN
# 545             NaN
# 289             NaN
# 581             NaN
# 925             NaN
# 952             NaN
# 390             NaN
# 786             NaN
# 727             NaN
# 383             NaN
# 895             NaN
# 76              NaN
# 306             NaN
# 34              NaN
# 689             NaN
# 132             NaN
# 852             NaN
# 638             NaN
# 890             NaN
# 686             NaN
# 370             NaN
# 411             NaN
# 124             NaN
# 725             NaN

# %%
# сортируем по 3 колонкам, вид сортировки указываем отдельно для каждой
st_df.sort_values(["race/ethnicity","parental level of education","math score"], ascending=[True, True,False]).head(30)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 539    male        group A          associate's degree      standard
# 614  female        group A          associate's degree      standard
# 489    male        group A          associate's degree  free/reduced
# 936    male        group A          associate's degree      standard
# 490  female        group A          associate's degree  free/reduced
# 653  female        group A          associate's degree      standard
# 356    male        group A          associate's degree      standard
# 62     male        group A          associate's degree  free/reduced
# 112    male        group A          associate's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 575    male        group A          associate's degree  free/reduced
# 741  female        group A          associate's degree  free/reduced
# 571    male        group A           bachelor's degree      standard
# 702    male        group A           bachelor's degree      standard
# 77     male        group A           bachelor's degree           NaN
# 151    male        group A           bachelor's degree      standard
# 464    male        group A           bachelor's degree      standard
# 379    male        group A           bachelor's degree      standard
# 832    male        group A           bachelor's degree      standard
# 705    male        group A           bachelor's degree  free/reduced
# 697  female        group A           bachelor's degree      standard
# 129  female        group A           bachelor's degree      standard
# 365    male        group A           bachelor's degree  free/reduced
# 816  female        group A           bachelor's degree      standard
# 468  female        group A                 high school  free/reduced
# 837  female        group A                 high school      standard
# 170    male        group A                 high school      standard
# 467    male        group A                 high school  free/reduced
# 635    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 539               completed          97           92.0           86.0
# 614                    none          82           93.0           93.0
# 489               completed          79           82.0           82.0
# 936                    none          67           57.0           53.0
# 490                    none          65           85.0           76.0
# 653               completed          65           70.0           74.0
# 356                    none          63           61.0           61.0
# 62                     none          62           61.0           55.0
# 112                    none          54           53.0           47.0
# 3                      none          47           57.0           44.0
# 72                     none          41           51.0           48.0
# 575               completed          40           55.0           53.0
# 741                    none          37           57.0           56.0
# 571                    none          91           96.0           92.0
# 702               completed          87           84.0           87.0
# 77                completed          80           78.0           81.0
# 151                     NaN          77           67.0           68.0
# 464               completed          75           58.0           62.0
# 379                    none          66           64.0           62.0
# 832                    none          64           60.0           58.0
# 705                    none          62           72.0           65.0
# 697                    none          59           72.0           70.0
# 129                    none          51           49.0           51.0
# 365                     NaN          49           58.0           60.0
# 816                    none          45           59.0           64.0
# 468               completed          77           88.0           85.0
# 837               completed          75           82.0           79.0
# 170               completed          72           73.0           74.0
# 467               completed          72           67.0           65.0
# 635                    none          71           74.0           64.0
#
#      speaking score
# 539             NaN
# 614             NaN
# 489             NaN
# 936             NaN
# 490             NaN
# 653             NaN
# 356             NaN
# 62              NaN
# 112             NaN
# 3               NaN
# 72              NaN
# 575             NaN
# 741             NaN
# 571             NaN
# 702             NaN
# 77              NaN
# 151             NaN
# 464             NaN
# 379             NaN
# 832             NaN
# 705             NaN
# 697             NaN
# 129             NaN
# 365             NaN
# 816             NaN
# 468             NaN
# 837             NaN
# 170             NaN
# 467             NaN
# 635             NaN

# %% [markdown]
# ### `.sort_index()` сортируем по индексу

# %%
# .sort_index(), параметры ascending = False, inplace=True работают также
st_df.sort_index(ascending = False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E                         NaN      standard
# 994    male            NaN                 high school      standard
# ..      ...            ...                         ...           ...
# 4      male        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 2    female        group B             master's degree      standard
# 1    female        group C                some college      standard
# 0    female        group B           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 999                    none          77           86.0           86.0
# 997               completed          59           71.0           65.0
# 996                     NaN          62           55.0           55.0
# 995               completed          88           99.0           95.0
# 994                    none          63           63.0           62.0
# ..                      ...         ...            ...            ...
# 4                      none          76           78.0           75.0
# 3                      none          47           57.0           44.0
# 2                      none          90           95.0           93.0
# 1                 completed          69           90.0           88.0
# 0                      none          72           72.0           74.0
#
#      speaking score
# 999             NaN
# 997             NaN
# 996             NaN
# 995             NaN
# 994             NaN
# ..              ...
# 4               NaN
# 3               NaN
# 2               NaN
# 1               NaN
# 0               NaN
#
# [995 rows x 9 columns]

# %% [markdown]
# ### `.rank()` для ранжирования (рейтинга)

# %%
#загружаем данные, students performance
st_df = pd.read_excel('studentsperformance7.xlsx')
st_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E                         NaN      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998     NaN            NaN                         NaN           NaN
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed        88.0           99.0           95.0
# 996                     NaN        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
# 998                     NaN         NaN            NaN            NaN
# 999                    none        77.0           86.0           86.0
#
#      speaking score
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 995             NaN
# 996             NaN
# 997             NaN
# 998             NaN
# 999             NaN
#
# [1000 rows x 9 columns]

# %%
# метод .rank()
# параметр ascending=False чтобы самые высокие оценки получили 1,2,3 места в рейтинге
st_df["math score"].rank(ascending = False).sort_values(ascending = False)
# Out:
# 59     995.0
# 980    994.0
# 17     993.0
# 787    992.0
# 145    991.0
#        ...
# 478      NaN
# 479      NaN
# 480      NaN
# 481      NaN
# 998      NaN
# Name: math score, Length: 1000, dtype: float64

# %%
#создаем колонку с рейтингом по математике
st_df["math rank"] = st_df["math score"].rank(ascending = False).sort_values(ascending = False)
st_df.sort_values("math score", ascending = False).head(20)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 263  female        group E                 high school           NaN
# 306    male        group E                some college      standard
# 114  female        group E           bachelor's degree      standard
# 104    male        group C                some college      standard
# 934    male        group C          associate's degree      standard
# 712  female        group D                some college      standard
# 179  female        group D            some high school      standard
# 864    male        group C          associate's degree      standard
# 286    male        group E          associate's degree      standard
# 34     male        group E                some college      standard
# 855  female        group B           bachelor's degree      standard
# 539    male        group A          associate's degree      standard
# 717  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none       100.0           92.0           97.0
# 625               completed       100.0           97.0           99.0
# 916               completed       100.0          100.0          100.0
# 149                     NaN       100.0          100.0           93.0
# 623               completed       100.0           96.0           86.0
# 962                    none       100.0          100.0          100.0
# 458                    none       100.0          100.0          100.0
# 263                    none        99.0           93.0           90.0
# 306               completed        99.0           87.0           81.0
# 114               completed        99.0          100.0          100.0
# 104               completed        98.0           86.0           90.0
# 934               completed        98.0           87.0           90.0
# 712                    none        98.0          100.0           99.0
# 179               completed        97.0          100.0          100.0
# 864                    none        97.0           93.0           91.0
# 286               completed        97.0           82.0           88.0
# 34                     none        97.0           87.0           82.0
# 855                    none        97.0           97.0           96.0
# 539               completed        97.0           92.0           86.0
# 717               completed        96.0           96.0           99.0
#
#      speaking score  math rank
# 451             NaN        4.0
# 625             NaN        4.0
# 916             NaN        4.0
# 149             NaN        4.0
# 623             NaN        4.0
# 962             NaN        4.0
# 458             NaN        4.0
# 263             NaN        9.0
# 306             NaN        9.0
# 114             NaN        9.0
# 104             NaN       12.0
# 934             NaN       12.0
# 712             NaN       12.0
# 179             NaN       16.5
# 864             NaN       16.5
# 286             NaN       16.5
# 34              NaN       16.5
# 855             NaN       16.5
# 539             NaN       16.5
# 717             NaN       21.0

# %%
# метод .astype(int) чтобы рейтинг был целочисленным
st_df["math rank"] = st_df["math score"].rank(ascending = False).sort_values(ascending = False).astype(int)
st_df.sort_values("math score", ascending = False).head(20)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 263  female        group E                 high school           NaN
# 306    male        group E                some college      standard
# 114  female        group E           bachelor's degree      standard
# 104    male        group C                some college      standard
# 934    male        group C          associate's degree      standard
# 712  female        group D                some college      standard
# 179  female        group D            some high school      standard
# 864    male        group C          associate's degree      standard
# 286    male        group E          associate's degree      standard
# 34     male        group E                some college      standard
# 855  female        group B           bachelor's degree      standard
# 539    male        group A          associate's degree      standard
# 717  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none       100.0           92.0           97.0
# 625               completed       100.0           97.0           99.0
# 916               completed       100.0          100.0          100.0
# 149                     NaN       100.0          100.0           93.0
# 623               completed       100.0           96.0           86.0
# 962                    none       100.0          100.0          100.0
# 458                    none       100.0          100.0          100.0
# 263                    none        99.0           93.0           90.0
# 306               completed        99.0           87.0           81.0
# 114               completed        99.0          100.0          100.0
# 104               completed        98.0           86.0           90.0
# 934               completed        98.0           87.0           90.0
# 712                    none        98.0          100.0           99.0
# 179               completed        97.0          100.0          100.0
# 864                    none        97.0           93.0           91.0
# 286               completed        97.0           82.0           88.0
# 34                     none        97.0           87.0           82.0
# 855                    none        97.0           97.0           96.0
# 539               completed        97.0           92.0           86.0
# 717               completed        96.0           96.0           99.0
#
#      speaking score  math rank
# 451             NaN          4
# 625             NaN          4
# 916             NaN          4
# 149             NaN          4
# 623             NaN          4
# 962             NaN          4
# 458             NaN          4
# 263             NaN          9
# 306             NaN          9
# 114             NaN          9
# 104             NaN         12
# 934             NaN         12
# 712             NaN         12
# 179             NaN         16
# 864             NaN         16
# 286             NaN         16
# 34              NaN         16
# 855             NaN         16
# 539             NaN         16
# 717             NaN         21

# %%
#метод .astype() - не сработает если есть Nulls

#метод .dropna() чтобы удалить Nulls
#параметр inplace=True, чтобы изменение было перманентным
st_df.dropna(how="all", inplace = True)

# %%
# метод .astype(int) чтобы рейтинг был целочисленным
st_df["math rank"] = st_df["math score"].rank(ascending = False).sort_values(ascending = False).astype(int)
st_df.sort_values("math score", ascending = False).head(20)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 263  female        group E                 high school           NaN
# 306    male        group E                some college      standard
# 114  female        group E           bachelor's degree      standard
# 104    male        group C                some college      standard
# 934    male        group C          associate's degree      standard
# 712  female        group D                some college      standard
# 179  female        group D            some high school      standard
# 864    male        group C          associate's degree      standard
# 286    male        group E          associate's degree      standard
# 34     male        group E                some college      standard
# 855  female        group B           bachelor's degree      standard
# 539    male        group A          associate's degree      standard
# 717  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none       100.0           92.0           97.0
# 625               completed       100.0           97.0           99.0
# 916               completed       100.0          100.0          100.0
# 149                     NaN       100.0          100.0           93.0
# 623               completed       100.0           96.0           86.0
# 962                    none       100.0          100.0          100.0
# 458                    none       100.0          100.0          100.0
# 263                    none        99.0           93.0           90.0
# 306               completed        99.0           87.0           81.0
# 114               completed        99.0          100.0          100.0
# 104               completed        98.0           86.0           90.0
# 934               completed        98.0           87.0           90.0
# 712                    none        98.0          100.0           99.0
# 179               completed        97.0          100.0          100.0
# 864                    none        97.0           93.0           91.0
# 286               completed        97.0           82.0           88.0
# 34                     none        97.0           87.0           82.0
# 855                    none        97.0           97.0           96.0
# 539               completed        97.0           92.0           86.0
# 717               completed        96.0           96.0           99.0
#
#      speaking score  math rank
# 451             NaN          4
# 625             NaN          4
# 916             NaN          4
# 149             NaN          4
# 623             NaN          4
# 962             NaN          4
# 458             NaN          4
# 263             NaN          9
# 306             NaN          9
# 114             NaN          9
# 104             NaN         12
# 934             NaN         12
# 712             NaN         12
# 179             NaN         16
# 864             NaN         16
# 286             NaN         16
# 34              NaN         16
# 855             NaN         16
# 539             NaN         16
# 717             NaN         21

# %%
#параметр method='dense', чтобы рейтинг начинался с 1 и прибавлял по 1
#method='average' - средний рейтинг группы (average rank of the group)
st_df["math rank"] = st_df["math score"].rank(ascending = False, method ='dense').sort_values(ascending = False).astype(int)
st_df.sort_values("math score", ascending = False).head(20)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 962  female        group E          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 263  female        group E                 high school           NaN
# 306    male        group E                some college      standard
# 114  female        group E           bachelor's degree      standard
# 104    male        group C                some college      standard
# 934    male        group C          associate's degree      standard
# 712  female        group D                some college      standard
# 179  female        group D            some high school      standard
# 864    male        group C          associate's degree      standard
# 286    male        group E          associate's degree      standard
# 34     male        group E                some college      standard
# 855  female        group B           bachelor's degree      standard
# 539    male        group A          associate's degree      standard
# 717  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none       100.0           92.0           97.0
# 625               completed       100.0           97.0           99.0
# 916               completed       100.0          100.0          100.0
# 149                     NaN       100.0          100.0           93.0
# 623               completed       100.0           96.0           86.0
# 962                    none       100.0          100.0          100.0
# 458                    none       100.0          100.0          100.0
# 263                    none        99.0           93.0           90.0
# 306               completed        99.0           87.0           81.0
# 114               completed        99.0          100.0          100.0
# 104               completed        98.0           86.0           90.0
# 934               completed        98.0           87.0           90.0
# 712                    none        98.0          100.0           99.0
# 179               completed        97.0          100.0          100.0
# 864                    none        97.0           93.0           91.0
# 286               completed        97.0           82.0           88.0
# 34                     none        97.0           87.0           82.0
# 855                    none        97.0           97.0           96.0
# 539               completed        97.0           92.0           86.0
# 717               completed        96.0           96.0           99.0
#
#      speaking score  math rank
# 451             NaN          1
# 625             NaN          1
# 916             NaN          1
# 149             NaN          1
# 623             NaN          1
# 962             NaN          1
# 458             NaN          1
# 263             NaN          2
# 306             NaN          2
# 114             NaN          2
# 104             NaN          3
# 934             NaN          3
# 712             NaN          3
# 179             NaN          4
# 864             NaN          4
# 286             NaN          4
# 34              NaN          4
# 855             NaN          4
# 539             NaN          4
# 717             NaN          5

# %% [markdown]
# ### условная фильтрация

# %%
st_df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 3             NaN         54
# 4             NaN         25

# %%
st_df["gender"] == "female"
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 994    False
# 995     True
# 996    False
# 997     True
# 999     True
# Name: gender, Length: 995, dtype: bool

# %%
#чтобы отфильтровать, оборачиваем в dfname[]
st_df[st_df["gender"] == "female"].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 5                    none        71.0           83.0           78.0
# 6               completed        88.0           95.0           92.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 5             NaN         30
# 6             NaN         13

# %%
#но лучше это делать в 2 шага для читабельности
females = st_df["gender"] == "female"
st_df[females].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 5                    none        71.0           83.0           78.0
# 6               completed        88.0           95.0           92.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 5             NaN         30
# 6             NaN         13

# %%
#все кроме female
not_females = st_df["gender"] != "female"
st_df[not_females].head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 10   male        group C          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score  \
# 3                     none        47.0           57.0           44.0
# 4                     none        76.0           78.0           75.0
# 7                     none        40.0           43.0           39.0
# 8                completed        64.0           64.0           67.0
# 10                    none        58.0           54.0           52.0
#
#     speaking score  math rank
# 3              NaN         54
# 4              NaN         25
# 7              NaN         61
# 8              NaN         37
# 10             NaN         43

# %%
#все у кого рейтинг по математике меньше 10
top_math = st_df["math rank"] < 10
st_df[top_math].head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 34                     none        97.0           87.0           82.0
# 104               completed        98.0           86.0           90.0
# 114               completed        99.0          100.0          100.0
# 149                     NaN       100.0          100.0           93.0
# 165               completed        96.0          100.0          100.0
#
#      speaking score  math rank
# 34              NaN          4
# 104             NaN          3
# 114             NaN          2
# 149             NaN          1
# 165             NaN          5

# %% [markdown]
# ### условная фильтрация `AND` (`&`) и `OR` (`|`)

# %%
#оператор AND - &
females = st_df["gender"] == "female"
top_math = st_df["math rank"] < 10
st_df[females & top_math]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 263  female        group E                 high school           NaN
# 451  female        group E                         NaN      standard
# 458  female        group E           bachelor's degree      standard
# 501  female        group B          associate's degree      standard
# 503  female        group E          associate's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 685  female        group E             master's degree      standard
# 712  female        group D                some college      standard
# 717  female        group C          associate's degree      standard
# 855  female        group B           bachelor's degree      standard
# 886  female        group E          associate's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 114               completed        99.0          100.0          100.0
# 165               completed        96.0          100.0          100.0
# 179               completed        97.0          100.0          100.0
# 263                    none        99.0           93.0           90.0
# 451                    none       100.0           92.0           97.0
# 458                    none       100.0          100.0          100.0
# 501               completed        94.0           87.0           92.0
# 503               completed        95.0           89.0           92.0
# 546               completed        92.0          100.0           97.0
# 566               completed        92.0          100.0          100.0
# 594               completed        92.0          100.0           99.0
# 685               completed        94.0           99.0          100.0
# 712                    none        98.0          100.0           99.0
# 717               completed        96.0           96.0           99.0
# 855                    none        97.0           97.0           96.0
# 886               completed        93.0          100.0           95.0
# 903               completed        93.0          100.0          100.0
# 957                    none        92.0          100.0          100.0
# 962                    none       100.0          100.0          100.0
#
#      speaking score  math rank
# 114             NaN          2
# 165             NaN          5
# 179             NaN          4
# 263             NaN          2
# 451             NaN          1
# 458             NaN          1
# 501             NaN          7
# 503             NaN          6
# 546             NaN          9
# 566             NaN          9
# 594             NaN          9
# 685             NaN          7
# 712             NaN          3
# 717             NaN          5
# 855             NaN          4
# 886             NaN          8
# 903             NaN          8
# 957             NaN          9
# 962             NaN          1

# %%
#оператор OR - |
females = st_df["gender"] == "female"
top_math = st_df["math rank"] < 10
st_df[females | top_math]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E                         NaN      standard
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 5                      none        71.0           83.0           78.0
# 6                 completed        88.0           95.0           92.0
# ..                      ...         ...            ...            ...
# 991               completed        65.0           82.0           78.0
# 992                    none        55.0           76.0           76.0
# 995               completed        88.0           99.0           95.0
# 997               completed        59.0           71.0           65.0
# 999                    none        77.0           86.0           86.0
#
#      speaking score  math rank
# 0               NaN         29
# 1               NaN         32
# 2               NaN         11
# 5               NaN         30
# 6               NaN         13
# ..              ...        ...
# 991             NaN         36
# 992             NaN         46
# 995             NaN         13
# 997             NaN         42
# 999             NaN         24
#
# [531 rows x 10 columns]

# %%
#оператор AND и OR вместе
females = st_df["gender"] == "female"
top_math = st_df["math rank"] < 10
high_reading = st_df["reading score"] > 95
st_df[(females & top_math) | high_reading]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 263  female        group E                 high school           NaN
# 373  female        group D                some college      standard
# 381    male        group C          associate's degree      standard
# 403  female        group D                 high school      standard
# 451  female        group E                         NaN      standard
# 458  female        group E           bachelor's degree      standard
# 501  female        group B          associate's degree      standard
# 503  female        group E          associate's degree      standard
# 514  female        group B             master's degree  free/reduced
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 571    male        group A           bachelor's degree      standard
# 580  female        group D            some high school      standard
# 594  female        group C           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 685  female        group E             master's degree      standard
# 712  female        group D                some college      standard
# 717  female        group C          associate's degree      standard
# 855  female        group B           bachelor's degree      standard
# 886  female        group E          associate's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
# 919    male        group B                some college      standard
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
# 995  female        group E                         NaN      standard
#
#     test preparation course  math score  reading score  writing score  \
# 106                    none        87.0          100.0          100.0
# 114               completed        99.0          100.0          100.0
# 149                     NaN       100.0          100.0           93.0
# 165               completed        96.0          100.0          100.0
# 179               completed        97.0          100.0          100.0
# 263                    none        99.0           93.0           90.0
# 373               completed        82.0           97.0           96.0
# 381               completed        87.0          100.0           95.0
# 403               completed        88.0           99.0          100.0
# 451                    none       100.0           92.0           97.0
# 458                    none       100.0          100.0          100.0
# 501               completed        94.0           87.0           92.0
# 503               completed        95.0           89.0           92.0
# 514               completed        77.0           97.0           94.0
# 546               completed        92.0          100.0           97.0
# 566               completed        92.0          100.0          100.0
# 571                    none        91.0           96.0           92.0
# 580                    none        81.0           97.0           96.0
# 594               completed        92.0          100.0           99.0
# 623               completed       100.0           96.0           86.0
# 625               completed       100.0           97.0           99.0
# 685               completed        94.0           99.0          100.0
# 712                    none        98.0          100.0           99.0
# 717               completed        96.0           96.0           99.0
# 855                    none        97.0           97.0           96.0
# 886               completed        93.0          100.0           95.0
# 903               completed        93.0          100.0          100.0
# 916               completed       100.0          100.0          100.0
# 919               completed        91.0           96.0           91.0
# 957                    none        92.0          100.0          100.0
# 962                    none       100.0          100.0          100.0
# 970                    none        89.0          100.0          100.0
# 995               completed        88.0           99.0           95.0
#
#      speaking score  math rank
# 106             NaN         14
# 114             NaN          2
# 149             NaN          1
# 165             NaN          5
# 179             NaN          4
# 263             NaN          2
# 373             NaN         19
# 381             NaN         14
# 403             NaN         13
# 451             NaN          1
# 458             NaN          1
# 501             NaN          7
# 503             NaN          6
# 514             NaN         24
# 546             NaN          9
# 566             NaN          9
# 571             NaN         10
# 580             NaN         20
# 594             NaN          9
# 623             NaN          1
# 625             NaN          1
# 685             NaN          7
# 712             NaN          3
# 717             NaN          5
# 855             NaN          4
# 886             NaN          8
# 903             NaN          8
# 916             NaN          1
# 919             NaN         10
# 957             NaN          9
# 962             NaN          1
# 970             NaN         12
# 995             NaN         13

# %% [markdown]
# ### `.isin()` метод

# %%
#нам нужны студенты из 3 групп, отфильтруем с помощью OR
groupA = st_df["race/ethnicity"] == "group A"
groupB = st_df["race/ethnicity"] == "group B"
groupC = st_df["race/ethnicity"] == "group C"
st_df[groupA|groupB|groupC]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
# 991  female        group B            some high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 986                    none        40.0           59.0           51.0
# 988                    none        44.0           45.0           45.0
# 991               completed        65.0           82.0           78.0
# 996                     NaN        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
#
#      speaking score  math rank
# 0               NaN         29
# 1               NaN         32
# 2               NaN         11
# 3               NaN         54
# 4               NaN         25
# ..              ...        ...
# 986             NaN         61
# 988             NaN         57
# 991             NaN         36
# 996             NaN         39
# 997             NaN         42
#
# [590 rows x 10 columns]

# %%
# метод .isin() упрощает задачу и делает код более читабельным
groupABC = st_df["race/ethnicity"].isin(["group A", "group B", "group C"])
st_df[groupABC]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
# 991  female        group B            some high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 986                    none        40.0           59.0           51.0
# 988                    none        44.0           45.0           45.0
# 991               completed        65.0           82.0           78.0
# 996                     NaN        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
#
#      speaking score  math rank
# 0               NaN         29
# 1               NaN         32
# 2               NaN         11
# 3               NaN         54
# 4               NaN         25
# ..              ...        ...
# 986             NaN         61
# 988             NaN         57
# 991             NaN         36
# 996             NaN         39
# 997             NaN         42
#
# [590 rows x 10 columns]

# %% [markdown]
# ### `.between()` метод

# %%
# оценка от 50 до 70 баллов
math50to70 = st_df["math score"].between(50,70)
st_df[math50to70]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 8      male        group D                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 12      NaN        group B                 high school      standard
# 14      NaN        group A             master's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993     NaN        group D           bachelor's degree  free/reduced
# 994    male            NaN                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 1                 completed        69.0           90.0           88.0
# 8                 completed        64.0           64.0           67.0
# 10                     none        58.0           54.0           52.0
# 12                     none        65.0           81.0           73.0
# 14                     none        50.0           53.0           58.0
# ..                      ...         ...            ...            ...
# 992                    none        55.0           76.0           76.0
# 993                    none        62.0           72.0           74.0
# 994                    none        63.0           63.0           62.0
# 996                     NaN        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
#
#      speaking score  math rank
# 1               NaN         32
# 8               NaN         37
# 10              NaN         43
# 12              NaN         36
# 14              NaN         51
# ..              ...        ...
# 992             NaN         46
# 993             NaN         39
# 994             NaN         38
# 996             NaN         39
# 997             NaN         42
#
# [471 rows x 10 columns]

# %%
#оператор AND и OR вместе
females = st_df["gender"] == "female"
top_math = st_df["math score"] < 60
high_reading = st_df["reading score"] > 95
st_df[(females & top_math) | high_reading]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 32   female        group E             master's degree  free/reduced
# 37   female        group D            some high school  free/reduced
# 41   female        group C          associate's degree      standard
# 42   female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E                         NaN      standard
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 9                      none        38.0           60.0           50.0
# 32                     none        56.0           72.0           65.0
# 37                     none        50.0           64.0           59.0
# 41                     none        58.0           73.0           68.0
# 42                     none        53.0           58.0           65.0
# ..                      ...         ...            ...            ...
# 986                    none        40.0           59.0           51.0
# 988                    none        44.0           45.0           45.0
# 992                    none        55.0           76.0           76.0
# 995               completed        88.0           99.0           95.0
# 997               completed        59.0           71.0           65.0
#
#      speaking score
# 9               NaN
# 32              NaN
# 37              NaN
# 41              NaN
# 42              NaN
# ..              ...
# 986             NaN
# 988             NaN
# 992             NaN
# 995             NaN
# 997             NaN
#
# [221 rows x 9 columns]

# %%
females1 = st_df["gender"] == "female"
groupA = st_df["race/ethnicity"] == "group A"
groupD = st_df["race/ethnicity"] == "group D"
high_reading = st_df["reading score"] > 90
high_writing = st_df["writing score"] > 90
high_speaking = st_df["speaking score"] > 90

st_df[(females1 & (groupA | groupD)) | high_reading | high_writing | high_speaking]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 29   female        group D             master's degree      standard
# 30   female        group D                some college      standard
# 36   female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 988  female        group A            some high school  free/reduced
# 989  female        group D                some college  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E                         NaN      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 2                      none        90.0           95.0           93.0
# 6                 completed        88.0           95.0           92.0
# 29                     none        62.0           70.0           75.0
# 30                     none        69.0           74.0           74.0
# 36                     none        74.0           81.0           83.0
# ..                      ...         ...            ...            ...
# 988                    none        44.0           45.0           45.0
# 989               completed        67.0           86.0           83.0
# 992                    none        55.0           76.0           76.0
# 995               completed        88.0           99.0           95.0
# 999                    none        77.0           86.0           86.0
#
#      speaking score
# 2               NaN
# 6               NaN
# 29              NaN
# 30              NaN
# 36              NaN
# ..              ...
# 988             NaN
# 989             NaN
# 992             NaN
# 995             NaN
# 999             NaN
#
# [218 rows x 9 columns]
