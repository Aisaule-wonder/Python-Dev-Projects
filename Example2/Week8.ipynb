# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### загружаем датафрейм

# %%
#загружаем данные, students performance
st_df = pd.read_excel('studentsperformance7.xlsx')
st_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 #загружаем данные, students performance
# ----> 2 st_df = pd.read_excel('studentsperformance7.xlsx')
#       3 st_df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1563, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1561     ext = "xls"
#    1562 else:
# -> 1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
#    1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1419, in inspect_excel_format(content_or_path, storage_options)
#    1416 if isinstance(content_or_path, bytes):
#    1417     content_or_path = BytesIO(content_or_path)
# -> 1419 with get_handle(
#    1420     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1421 ) as handle:
#    1422     stream = handle.handle
#    1423     stream.seek(0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'studentsperformance7.xlsx'

# %%
#метод .info() - типы данных и сколько памяти занимает наш датасет
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    object
#  1   race/ethnicity               985 non-null    object
#  2   parental level of education  955 non-null    object
#  3   lunch                        967 non-null    object
#  4   test preparation course      956 non-null    object
#  5   math score                   995 non-null    float64
#  6   reading score                995 non-null    float64
#  7   writing score                995 non-null    float64
#  8   speaking score               0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 70.4+ KB

# %%
#атрибут .dtypes
st_df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# speaking score                 float64
# dtype: object

# %% [markdown]
# ###  `.astype()`  метод чтобы поменять тип данных

# %%
#метод .astype() - не сработает если есть Nulls
st_df["math score"] = st_df["math score"].astype("int")
st_df["math score"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a4d05c42ee99> in <module>
#       1 #метод .astype() - не сработает если есть Nulls
# ----> 2 st_df["math score"] = st_df["math score"].astype("int")
#       3 st_df["math score"]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     866
#     867         if not np.isfinite(arr).all():
# --> 868             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     869
#     870     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
#метод .dropna() чтобы удалить Nulls, обязательно указать параметр inplace=True 
#чтобы изменение было перманентным, то есть чтобы на самом деле удалить в исходном датасете
#how="all" указывает на то, что мы удаляем строки полностью состоящие из NA.
#how="any" удаляет строки, где хотя бы один раз встречается NA.
st_df.dropna(how = "all", inplace = True)

# %%
#удалили Nulls, пробуем снова - сработало!
st_df["math score"] = st_df["math score"].astype("int")
st_df["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 994    63
# 995    88
# 996    62
# 997    59
# 999    77
# Name: math score, Length: 995, dtype: int32

# %% [markdown]
# ###  методы `unique` и `nunique()`

# %%
#.nunique() - кол-во уникальных значений в колонке без учета NaN - по умолчанию
st_df["race/ethnicity"].nunique()
# Out:
# 5

# %%
#.unique() - список уникальных значений в колонке 
st_df["race/ethnicity"].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E', nan],
#       dtype=object)

# %%
#.nunique() - кол-во уникальных значений в колонке, параметр dropna=False - с учетом NaN 
st_df["race/ethnicity"].nunique(dropna=False)
# Out:
# 6

# %% [markdown]
# ###  категории в Pandas

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 995 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    object
#  1   race/ethnicity               985 non-null    object
#  2   parental level of education  955 non-null    object
#  3   lunch                        967 non-null    object
#  4   test preparation course      956 non-null    object
#  5   math score                   995 non-null    int32
#  6   reading score                995 non-null    float64
#  7   writing score                995 non-null    float64
#  8   speaking score               0 non-null      float64
# dtypes: float64(3), int32(1), object(5)
# memory usage: 73.8+ KB

# %%
#Если есть категориальные данные (пол, раса, уровень образования и тп), 
# mо категории могут сэкономить память
# .astype("category") конвертируем в категорию
st_df["race/ethnicity"] = st_df["race/ethnicity"].astype("category")
st_df["gender"] = st_df["gender"].astype("category")

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 995 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       984 non-null    category
#  1   race/ethnicity               985 non-null    category
#  2   parental level of education  955 non-null    object
#  3   lunch                        967 non-null    object
#  4   test preparation course      956 non-null    object
#  5   math score                   995 non-null    int32
#  6   reading score                995 non-null    float64
#  7   writing score                995 non-null    float64
#  8   speaking score               0 non-null      float64
# dtypes: category(2), float64(3), int32(1), object(3)
# memory usage: 60.6+ KB

# %% [markdown]
# ### `.sort_values()` сортируем по значениям

# %%
st_df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
# 5                    none          71           83.0           78.0
# 6               completed          88           95.0           92.0
# 7                    none          40           43.0           39.0
# 8               completed          64           64.0           67.0
# 9                    none          38           60.0           50.0
#
#    speaking score
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN

# %%
# .sort_values() сортирует по колонке
st_df.sort_values("race/ethnicity")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 395    male        group A                 high school  free/reduced
# 490  female        group A          associate's degree  free/reduced
# 546  female        group A            some high school      standard
# 778  female        group A                some college      standard
# 384  female        group A            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 217  female            NaN                 high school  free/reduced
# 218    male            NaN                 high school  free/reduced
# 219    male            NaN            some high school      standard
# 220  female            NaN                 high school      standard
# 994    male            NaN                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 395                    none          48           45.0           41.0
# 490                    none          65           85.0           76.0
# 546               completed          92          100.0           97.0
# 778               completed          72           79.0           82.0
# 384                    none          38           43.0           43.0
# ..                      ...         ...            ...            ...
# 217                    none          34           42.0           39.0
# 218                    none          66           77.0           70.0
# 219               completed          61           56.0           56.0
# 220               completed          56           68.0           74.0
# 994                    none          63           63.0           62.0
#
#      speaking score
# 395             NaN
# 490             NaN
# 546             NaN
# 778             NaN
# 384             NaN
# ..              ...
# 217             NaN
# 218             NaN
# 219             NaN
# 220             NaN
# 994             NaN
#
# [995 rows x 9 columns]

# %%
#.sort_values() сортирует по колонке, параметр ascending=False чтобы по убыванию
st_df.sort_values("race/ethnicity", ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 386  female        group E           bachelor's degree      standard
# 845    male        group E             master's degree      standard
# 533  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 532    male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 217  female            NaN                 high school  free/reduced
# 218    male            NaN                 high school  free/reduced
# 219    male            NaN            some high school      standard
# 220  female            NaN                 high school      standard
# 994    male            NaN                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 386                    none          64           73.0           70.0
# 845                    none          90           85.0           84.0
# 533               completed          79           88.0           94.0
# 149                     NaN         100          100.0           93.0
# 532               completed          62           61.0           58.0
# ..                      ...         ...            ...            ...
# 217                    none          34           42.0           39.0
# 218                    none          66           77.0           70.0
# 219               completed          61           56.0           56.0
# 220               completed          56           68.0           74.0
# 994                    none          63           63.0           62.0
#
#      speaking score
# 386             NaN
# 845             NaN
# 533             NaN
# 149             NaN
# 532             NaN
# ..              ...
# 217             NaN
# 218             NaN
# 219             NaN
# 220             NaN
# 994             NaN
#
# [995 rows x 9 columns]

# %%
# NaN по умолчанию в конце, параметр na_position = "first" чтобы NaN попали в начало
st_df.sort_values("race/ethnicity", ascending=False, na_position="first")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 212  female            NaN                 high school  free/reduced
# 213    male            NaN          associate's degree  free/reduced
# 214    male            NaN                 high school      standard
# 215    male            NaN            some high school      standard
# 216  female            NaN          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 830  female        group A                some college  free/reduced
# 296    male        group A            some high school      standard
# 300    male        group A                some college  free/reduced
# 832    male        group A           bachelor's degree      standard
# 365    male        group A           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 212                    none          42           62.0           60.0
# 213               completed          60           51.0           56.0
# 214               completed          87           91.0           81.0
# 215               completed          84           83.0           75.0
# 216               completed          83           86.0           88.0
# ..                      ...         ...            ...            ...
# 830                    none          61           60.0           57.0
# 296               completed          46           41.0           43.0
# 300               completed          81           78.0           81.0
# 832                    none          64           60.0           58.0
# 365                     NaN          49           58.0           60.0
#
#      speaking score
# 212             NaN
# 213             NaN
# 214             NaN
# 215             NaN
# 216             NaN
# ..              ...
# 830             NaN
# 296             NaN
# 300             NaN
# 832             NaN
# 365             NaN
#
# [995 rows x 9 columns]

# %%
# сортируем по 3 колонкам
st_df.sort_values(["race/ethnicity", "parental level of education", "math score"], ascending=False).head(30)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 575    male        group A          associate's degree  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 3      male        group A          associate's degree  free/reduced
# 112    male        group A          associate's degree      standard
# ..      ...            ...                         ...           ...
# 994    male            NaN                 high school      standard
# 218    male            NaN                 high school  free/reduced
# 214    male            NaN                 high school      standard
# 219    male            NaN            some high school      standard
# 215    male            NaN            some high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37           57.0           56.0
# 575               completed          40           55.0           53.0
# 72                     none          41           51.0           48.0
# 3                      none          47           57.0           44.0
# 112                    none          54           53.0           47.0
# ..                      ...         ...            ...            ...
# 994                    none          63           63.0           62.0
# 218                    none          66           77.0           70.0
# 214               completed          87           91.0           81.0
# 219               completed          61           56.0           56.0
# 215               completed          84           83.0           75.0
#
#      speaking score
# 741             NaN
# 575             NaN
# 72              NaN
# 3               NaN
# 112             NaN
# ..              ...
# 994             NaN
# 218             NaN
# 214             NaN
# 219             NaN
# 215             NaN
#
# [995 rows x 9 columns]

# %%
# сортируем по 3 колонкам, вид сортировки указываем отдельно для каждой
st_df.sort_values(["race/ethnicity", "parental level of education", "math score"], ascending=[True, True, False]).head(30)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 539    male        group A          associate's degree      standard
# 614  female        group A          associate's degree      standard
# 489    male        group A          associate's degree  free/reduced
# 936    male        group A          associate's degree      standard
# 490  female        group A          associate's degree  free/reduced
# 653  female        group A          associate's degree      standard
# 356    male        group A          associate's degree      standard
# 62     male        group A          associate's degree  free/reduced
# 112    male        group A          associate's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 575    male        group A          associate's degree  free/reduced
# 741  female        group A          associate's degree  free/reduced
# 571    male        group A           bachelor's degree      standard
# 702    male        group A           bachelor's degree      standard
# 77     male        group A           bachelor's degree           NaN
# 151    male        group A           bachelor's degree      standard
# 464    male        group A           bachelor's degree      standard
# 379    male        group A           bachelor's degree      standard
# 832    male        group A           bachelor's degree      standard
# 705    male        group A           bachelor's degree  free/reduced
# 697  female        group A           bachelor's degree      standard
# 129  female        group A           bachelor's degree      standard
# 365    male        group A           bachelor's degree  free/reduced
# 816  female        group A           bachelor's degree      standard
# 468  female        group A                 high school  free/reduced
# 837  female        group A                 high school      standard
# 170    male        group A                 high school      standard
# 467    male        group A                 high school  free/reduced
# 635    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 539               completed          97           92.0           86.0
# 614                    none          82           93.0           93.0
# 489               completed          79           82.0           82.0
# 936                    none          67           57.0           53.0
# 490                    none          65           85.0           76.0
# 653               completed          65           70.0           74.0
# 356                    none          63           61.0           61.0
# 62                     none          62           61.0           55.0
# 112                    none          54           53.0           47.0
# 3                      none          47           57.0           44.0
# 72                     none          41           51.0           48.0
# 575               completed          40           55.0           53.0
# 741                    none          37           57.0           56.0
# 571                    none          91           96.0           92.0
# 702               completed          87           84.0           87.0
# 77                completed          80           78.0           81.0
# 151                     NaN          77           67.0           68.0
# 464               completed          75           58.0           62.0
# 379                    none          66           64.0           62.0
# 832                    none          64           60.0           58.0
# 705                    none          62           72.0           65.0
# 697                    none          59           72.0           70.0
# 129                    none          51           49.0           51.0
# 365                     NaN          49           58.0           60.0
# 816                    none          45           59.0           64.0
# 468               completed          77           88.0           85.0
# 837               completed          75           82.0           79.0
# 170               completed          72           73.0           74.0
# 467               completed          72           67.0           65.0
# 635                    none          71           74.0           64.0
#
#      speaking score
# 539             NaN
# 614             NaN
# 489             NaN
# 936             NaN
# 490             NaN
# 653             NaN
# 356             NaN
# 62              NaN
# 112             NaN
# 3               NaN
# 72              NaN
# 575             NaN
# 741             NaN
# 571             NaN
# 702             NaN
# 77              NaN
# 151             NaN
# 464             NaN
# 379             NaN
# 832             NaN
# 705             NaN
# 697             NaN
# 129             NaN
# 365             NaN
# 816             NaN
# 468             NaN
# 837             NaN
# 170             NaN
# 467             NaN
# 635             NaN

# %% [markdown]
# ### `.sort_index()` сортируем по индексу

# %%
# .sort_index(), параметры ascending = False, inplace=True работают также
st_df.sort_index(ascending = False, inplace=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E                         NaN      standard
# 994    male            NaN                 high school      standard
# ..      ...            ...                         ...           ...
# 4      male        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 2    female        group B             master's degree      standard
# 1    female        group C                some college      standard
# 0    female        group B           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 999                    none          77           86.0           86.0
# 997               completed          59           71.0           65.0
# 996                     NaN          62           55.0           55.0
# 995               completed          88           99.0           95.0
# 994                    none          63           63.0           62.0
# ..                      ...         ...            ...            ...
# 4                      none          76           78.0           75.0
# 3                      none          47           57.0           44.0
# 2                      none          90           95.0           93.0
# 1                 completed          69           90.0           88.0
# 0                      none          72           72.0           74.0
#
#      speaking score
# 999             NaN
# 997             NaN
# 996             NaN
# 995             NaN
# 994             NaN
# ..              ...
# 4               NaN
# 3               NaN
# 2               NaN
# 1               NaN
# 0               NaN
#
# [995 rows x 9 columns]

# %% [markdown]
# ### `.rank()` для ранжирования (рейтинга)

# %%
#загружаем данные, students performance
st_df = pd.read_excel('studentsperformance7.xlsx')
st_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E                         NaN      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998     NaN            NaN                         NaN           NaN
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed        88.0           99.0           95.0
# 996                     NaN        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
# 998                     NaN         NaN            NaN            NaN
# 999                    none        77.0           86.0           86.0
#
#      speaking score
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 995             NaN
# 996             NaN
# 997             NaN
# 998             NaN
# 999             NaN
#
# [1000 rows x 9 columns]

# %%
# метод .rank()
# параметр ascending=False чтобы самые высокие оценки получили 1,2,3 места в рейтинге
st_df["math score"].rank().sort_values(ascending=False)
# Out:
# 625    992.0
# 962    992.0
# 149    992.0
# 458    992.0
# 451    992.0
#        ...
# 145      5.0
# 787      4.0
# 17       3.0
# 980      2.0
# 59       1.0
# Name: math score, Length: 995, dtype: float64

# %%
#создаем колонку с рейтингом по математике
#Мы може заметить, что рейтинги созданные rank() не целочисленные по умолчанию, а имеют float значения.
st_df["math rank"] = st_df["math score"].rank(ascending=False).sort_values(ascending=False)
st_df.sort_values("math score", ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17      NaN        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100           92.0           97.0
# 625               completed         100           97.0           99.0
# 916               completed         100          100.0          100.0
# 149                     NaN         100          100.0           93.0
# 623               completed         100           96.0           86.0
# ..                      ...         ...            ...            ...
# 145                     NaN          22           39.0           33.0
# 787                    none          19           38.0           32.0
# 17                     none          18           32.0           28.0
# 980                    none           8           24.0           23.0
# 59                     none           0           17.0           10.0
#
#      speaking score  math rank
# 451             NaN        4.0
# 625             NaN        4.0
# 916             NaN        4.0
# 149             NaN        4.0
# 623             NaN        4.0
# ..              ...        ...
# 145             NaN      991.0
# 787             NaN      992.0
# 17              NaN      993.0
# 980             NaN      994.0
# 59              NaN      995.0
#
# [995 rows x 10 columns]

# %%
# метод .astype(int) чтобы рейтинг был целочисленным
st_df["math rank"] = st_df["math score"].rank(ascending=False).sort_values(ascending=False).astype("int")
st_df.sort_values("math score", ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17      NaN        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100           92.0           97.0
# 625               completed         100           97.0           99.0
# 916               completed         100          100.0          100.0
# 149                     NaN         100          100.0           93.0
# 623               completed         100           96.0           86.0
# ..                      ...         ...            ...            ...
# 145                     NaN          22           39.0           33.0
# 787                    none          19           38.0           32.0
# 17                     none          18           32.0           28.0
# 980                    none           8           24.0           23.0
# 59                     none           0           17.0           10.0
#
#      speaking score  math rank
# 451             NaN          4
# 625             NaN          4
# 916             NaN          4
# 149             NaN          4
# 623             NaN          4
# ..              ...        ...
# 145             NaN        991
# 787             NaN        992
# 17              NaN        993
# 980             NaN        994
# 59              NaN        995
#
# [995 rows x 10 columns]

# %%
#параметр method='dense', чтобы рейтинг начинался с 1 и прибавлял по 1
#method='average' - средний рейтинг группы (average rank of the group)
st_df["math rank"] = st_df["math score"].rank(ascending=False, method="dense").sort_values(ascending=False).astype("int")
st_df.sort_values("math score", ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 451  female        group E                         NaN      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17      NaN        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100           92.0           97.0
# 625               completed         100           97.0           99.0
# 916               completed         100          100.0          100.0
# 149                     NaN         100          100.0           93.0
# 623               completed         100           96.0           86.0
# ..                      ...         ...            ...            ...
# 145                     NaN          22           39.0           33.0
# 787                    none          19           38.0           32.0
# 17                     none          18           32.0           28.0
# 980                    none           8           24.0           23.0
# 59                     none           0           17.0           10.0
#
#      speaking score  math rank
# 451             NaN          1
# 625             NaN          1
# 916             NaN          1
# 149             NaN          1
# 623             NaN          1
# ..              ...        ...
# 145             NaN         77
# 787             NaN         78
# 17              NaN         79
# 980             NaN         80
# 59              NaN         81
#
# [995 rows x 10 columns]

# %% [markdown]
# ### условная фильтрация

# %%
st_df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 3             NaN         54
# 4             NaN         25

# %%
st_df["gender"] == "female"
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 994    False
# 995     True
# 996    False
# 997     True
# 999     True
# Name: gender, Length: 995, dtype: bool

# %%
#чтобы отфильтровать, оборачиваем в dfname[]
st_df[st_df["gender"] == "female"].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 5                    none          71           83.0           78.0
# 6               completed          88           95.0           92.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 5             NaN         30
# 6             NaN         13

# %%
#но лучше это делать в 2 шага для читабельности
females = st_df["gender"] == "female"
st_df[females].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 5                    none          71           83.0           78.0
# 6               completed          88           95.0           92.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 5             NaN         30
# 6             NaN         13

# %%
#все кроме female
not_females = st_df["gender"] != "female"
st_df[not_females].head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 10   male        group C          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score  \
# 3                     none          47           57.0           44.0
# 4                     none          76           78.0           75.0
# 7                     none          40           43.0           39.0
# 8                completed          64           64.0           67.0
# 10                    none          58           54.0           52.0
#
#     speaking score  math rank
# 3              NaN         54
# 4              NaN         25
# 7              NaN         61
# 8              NaN         37
# 10             NaN         43

# %%
#все у кого рейтинг по математике меньше 10
top_math = st_df["math rank"] < 10
st_df[top_math].head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 34                     none          97           87.0           82.0
# 104               completed          98           86.0           90.0
# 114               completed          99          100.0          100.0
# 149                     NaN         100          100.0           93.0
# 165               completed          96          100.0          100.0
#
#      speaking score  math rank
# 34              NaN          4
# 104             NaN          3
# 114             NaN          2
# 149             NaN          1
# 165             NaN          5

# %% [markdown]
# ### условная фильтрация `AND` (`&`) и `OR` (`|`)

# %%
#оператор AND - &
# Здесь мы отображаем студентов, которые входят в ТОП-10 по оценке по математике и одновременно являются девушками
females = st_df["gender"] == "female"
top_math = st_df["math rank"] < 10
st_df[females&top_math].head()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 114  female        group E           bachelor's degree  standard
# 165  female        group C           bachelor's degree  standard
# 179  female        group D            some high school  standard
# 263  female        group E                 high school       NaN
# 451  female        group E                         NaN  standard
#
#     test preparation course  math score  reading score  writing score  \
# 114               completed          99          100.0          100.0
# 165               completed          96          100.0          100.0
# 179               completed          97          100.0          100.0
# 263                    none          99           93.0           90.0
# 451                    none         100           92.0           97.0
#
#      speaking score  math rank
# 114             NaN          2
# 165             NaN          5
# 179             NaN          4
# 263             NaN          2
# 451             NaN          1

# %%
#оператор OR - |
# Здесь мы отображаем студентов, которые или входят в ТОП-10 по оценке по математике или являются девушками.
# Достаточно выполнение одного условия.
females = st_df["gender"] == "female"
top_math = st_df["math rank"] < 10
st_df[females|top_math].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 5                    none          71           83.0           78.0
# 6               completed          88           95.0           92.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 5             NaN         30
# 6             NaN         13

# %%
#оператор AND и OR вместе
females = st_df["gender"] == "female"
top_math = st_df["math rank"] < 10
high_reading = st_df["reading score"] > 95
st_df[(females & top_math) | high_reading].head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 106                    none          87          100.0          100.0
# 114               completed          99          100.0          100.0
# 149                     NaN         100          100.0           93.0
# 165               completed          96          100.0          100.0
# 179               completed          97          100.0          100.0
#
#      speaking score  math rank
# 106             NaN         14
# 114             NaN          2
# 149             NaN          1
# 165             NaN          5
# 179             NaN          4

# %% [markdown]
# ### `.isin()` метод

# %%
#нам нужны студенты из 3 групп, отфильтруем с помощью OR
groupA = st_df["race/ethnicity"] == "group A"
groupB = st_df["race/ethnicity"] == "group B"
groupC = st_df["race/ethnicity"] == "group C"
st_df[groupA | groupB | groupC].head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 3             NaN         54
# 4             NaN         25

# %%
# метод .isin() упрощает задачу и делает код более читабельным
groupABC = st_df["race/ethnicity"].isin(["group A", "group B", "group C"])
st_df[groupABC].head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1               completed          69           90.0           88.0
# 2                    none          90           95.0           93.0
# 3                    none          47           57.0           44.0
# 4                    none          76           78.0           75.0
#
#    speaking score  math rank
# 0             NaN         29
# 1             NaN         32
# 2             NaN         11
# 3             NaN         54
# 4             NaN         25

# %% [markdown]
# ### `.between()` метод

# %%
# оценка от 50 до 70 баллов
math50to70 = st_df["math score"].between(50, 70)
st_df[math50to70].head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 1   female        group C                some college      standard
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 12     NaN        group B                 high school      standard
# 14     NaN        group A             master's degree      standard
#
#    test preparation course  math score  reading score  writing score  \
# 1                completed          69           90.0           88.0
# 8                completed          64           64.0           67.0
# 10                    none          58           54.0           52.0
# 12                    none          65           81.0           73.0
# 14                    none          50           53.0           58.0
#
#     speaking score  math rank
# 1              NaN         32
# 8              NaN         37
# 10             NaN         43
# 12             NaN         36
# 14             NaN         51

# %%
#загружаем данные, students performance
st_df = pd.read_excel(r'C:\Users\77785\Downloads\studentsperformance8.xlsx')
st_df
# Out:
#       ID  gender race/ethnicity parental level of education         lunch  \
# 0      1  female        group B           bachelor's degree      standard
# 1      2  female        group C                some college      standard
# 2      3  female        group B             master's degree      standard
# 3      4    male        group A          associate's degree  free/reduced
# 4      5    male        group C                some college      standard
# ...   ..     ...            ...                         ...           ...
# 1072   4    male        group A          associate's degree  free/reduced
# 1073   5    male        group C                some college      standard
# 1074   6  female        group B          associate's degree      standard
# 1075   7  female        group B                some college      standard
# 1076   8    male        group B                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score
# 0                       none          72             72             74
# 1                  completed          69             90             88
# 2                       none          90             95             93
# 3                       none          47             57             44
# 4                       none          76             78             75
# ...                      ...         ...            ...            ...
# 1072                    none          47             57             44
# 1073                    none          76             78             75
# 1074                    none          71             83             78
# 1075               completed          88             95             92
# 1076                    none          40             43             39
#
# [1077 rows x 9 columns]

# %%
#метод .sort_values() - видим что есть дубли
st_df.sort_values('ID').head(20)
# Out:
#       ID  gender race/ethnicity parental level of education         lunch  \
# 0      1  female        group B           bachelor's degree      standard
# 1      2  female        group C                some college      standard
# 2      3  female        group B             master's degree      standard
# 3      4    male        group A          associate's degree  free/reduced
# 1072   4    male        group A          associate's degree  free/reduced
# 4      5    male        group C                some college      standard
# 1073   5    male        group C                some college      standard
# 5      6  female        group B          associate's degree      standard
# 1074   6  female        group B          associate's degree      standard
# 6      7  female        group B                some college      standard
# 1075   7  female        group B                some college      standard
# 1076   8    male        group B                some college  free/reduced
# 7      8    male        group B                some college  free/reduced
# 8      9    male        group D                 high school  free/reduced
# 9     10  female        group B                 high school  free/reduced
# 10    11    male        group C          associate's degree      standard
# 11    12    male        group D          associate's degree      standard
# 12    13  female        group B                 high school      standard
# 13    14    male        group A                some college      standard
# 14    15  female        group A             master's degree      standard
#
#      test preparation course  math score  reading score  writing score
# 0                       none          72             72             74
# 1                  completed          69             90             88
# 2                       none          90             95             93
# 3                       none          47             57             44
# 1072                    none          47             57             44
# 4                       none          76             78             75
# 1073                    none          76             78             75
# 5                       none          71             83             78
# 1074                    none          71             83             78
# 6                  completed          88             95             92
# 1075               completed          88             95             92
# 1076                    none          40             43             39
# 7                       none          40             43             39
# 8                  completed          64             64             67
# 9                       none          38             60             50
# 10                      none          58             54             52
# 11                      none          40             52             43
# 12                      none          65             81             73
# 13                 completed          78             72             70
# 14                      none          50             53             58

# %% [markdown]
# ###  `.duplicated()`  метод чтобы найти дубли (повторяющиеся значения)

# %%
#метод .duplicated() - возвращает True/False если значение является/не является дублем
st_df["ID"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1072     True
# 1073     True
# 1074     True
# 1075     True
# 1076     True
# Name: ID, Length: 1077, dtype: bool

# %%
#метод .duplicated() параметр keep= 
#'first': Пометит все дубликаты как True, за исключением первого появления (по умолчанию)
#'last': Пометит все дубликаты как True, за исключением последнего появления.
# False : Пометит все дубликаты как True

st_df["has_duplicate"] =st_df["ID"].duplicated(keep = False)
st_df.sort_values('ID').head(20)
# Out:
#       ID  gender race/ethnicity parental level of education         lunch  \
# 0      1  female        group B           bachelor's degree      standard
# 1      2  female        group C                some college      standard
# 2      3  female        group B             master's degree      standard
# 3      4    male        group A          associate's degree  free/reduced
# 1072   4    male        group A          associate's degree  free/reduced
# 4      5    male        group C                some college      standard
# 1073   5    male        group C                some college      standard
# 5      6  female        group B          associate's degree      standard
# 1074   6  female        group B          associate's degree      standard
# 6      7  female        group B                some college      standard
# 1075   7  female        group B                some college      standard
# 1076   8    male        group B                some college  free/reduced
# 7      8    male        group B                some college  free/reduced
# 8      9    male        group D                 high school  free/reduced
# 9     10  female        group B                 high school  free/reduced
# 10    11    male        group C          associate's degree      standard
# 11    12    male        group D          associate's degree      standard
# 12    13  female        group B                 high school      standard
# 13    14    male        group A                some college      standard
# 14    15  female        group A             master's degree      standard
#
#      test preparation course  math score  reading score  writing score  \
# 0                       none          72             72             74
# 1                  completed          69             90             88
# 2                       none          90             95             93
# 3                       none          47             57             44
# 1072                    none          47             57             44
# 4                       none          76             78             75
# 1073                    none          76             78             75
# 5                       none          71             83             78
# 1074                    none          71             83             78
# 6                  completed          88             95             92
# 1075               completed          88             95             92
# 1076                    none          40             43             39
# 7                       none          40             43             39
# 8                  completed          64             64             67
# 9                       none          38             60             50
# 10                      none          58             54             52
# 11                      none          40             52             43
# 12                      none          65             81             73
# 13                 completed          78             72             70
# 14                      none          50             53             58
#
#       has_duplicate
# 0             False
# 1             False
# 2             False
# 3              True
# 1072           True
# 4              True
# 1073           True
# 5              True
# 1074           True
# 6              True
# 1075           True
# 1076           True
# 7              True
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False

# %%
#кол-во строк с дублями
len(st_df)
# Out:
# 1077

# %%
#удаляем все дубли
#добавьте параметр inplace=True чтобы удалить "на самом деле"
len(st_df.drop_duplicates(keep = False))
# Out:
# 923

# %%
#оставляем первый экземпляр и удаляем остальные
#добавьте параметр inplace=True чтобы удалить "на самом деле"
len(st_df.drop_duplicates(keep = "first"))
# Out:
# 1000

# %%
#оставляем последний экземпляр и удаляем остальные
#добавьте параметр inplace=True чтобы удалить "на самом деле"
len(st_df.drop_duplicates(keep = "last"))
# Out:
# 1000

# %% [markdown]
# ###  установка и сброс индекса

# %%
#способa 1: устанавливаем индекс параметром index_col
states_df = pd.read_excel('states.xlsx', index_col = "Abbreviation")
states_df.head()
# Out:
#                    State Capital City  pop_rank       Pop  Growth   Pop2021  \
# Abbreviation
# AL               Alabama   Montgomery        24   5073187  0.0048   5048733
# AK                Alaska       Juneau        48    738023  0.0031    735707
# AZ               Arizona      Phoenix        14   7303398  0.0105   7227450
# AR              Arkansas  Little Rock        33   3030646  0.0032   3021085
# CA            California   Sacramento         1  39995077  0.0057  39766650
#
#                Pop2010  growthSince2010  Percent   density
# Abbreviation
# AL             4779736           0.0614   0.0151  100.1715
# AK              710231           0.0391   0.0022    1.2933
# AZ             6392017           0.1426   0.0218   64.2939
# AR             2915918           0.0393   0.0090   58.2425
# CA            37253956           0.0736   0.1193  256.7424

# %%
# способ 2: устанавливаем индекс методом .set_index()
# inplace=True чтобы сделать изменение постоянным
states_df = pd.read_excel('states.xlsx')
states_df.set_index("Abbreviation").head()
# Out:
#                    State Capital City  pop_rank       Pop  Growth   Pop2021  \
# Abbreviation
# AL               Alabama   Montgomery        24   5073187  0.0048   5048733
# AK                Alaska       Juneau        48    738023  0.0031    735707
# AZ               Arizona      Phoenix        14   7303398  0.0105   7227450
# AR              Arkansas  Little Rock        33   3030646  0.0032   3021085
# CA            California   Sacramento         1  39995077  0.0057  39766650
#
#                Pop2010  growthSince2010  Percent   density
# Abbreviation
# AL             4779736           0.0614   0.0151  100.1715
# AK              710231           0.0391   0.0022    1.2933
# AZ             6392017           0.1426   0.0218   64.2939
# AR             2915918           0.0393   0.0090   58.2425
# CA            37253956           0.0736   0.1193  256.7424

# %%
# сбрасываем индекс методом .reset_index()
# inplace=True чтобы сделать изменение постоянным
# drop=True чтобы не дублировать индекс в виде дополнительной колонки в датафрейме
states_df.reset_index(drop=True).head()
# Out:
#   Abbreviation       State Capital City  pop_rank       Pop  Growth   Pop2021  \
# 0           AL     Alabama   Montgomery        24   5073187  0.0048   5048733
# 1           AK      Alaska       Juneau        48    738023  0.0031    735707
# 2           AZ     Arizona      Phoenix        14   7303398  0.0105   7227450
# 3           AR    Arkansas  Little Rock        33   3030646  0.0032   3021085
# 4           CA  California   Sacramento         1  39995077  0.0057  39766650
#
#     Pop2010  growthSince2010  Percent   density
# 0   4779736           0.0614   0.0151  100.1715
# 1    710231           0.0391   0.0022    1.2933
# 2   6392017           0.1426   0.0218   64.2939
# 3   2915918           0.0393   0.0090   58.2425
# 4  37253956           0.0736   0.1193  256.7424

# %% [markdown]
# ### `.sort_index()` сортируем по индексу
# Оптимизация набора данных (датасета) с помощью сортировки по индексу является лучшей практикой(best practice), чтобы помочь pandas быть более эффективной при поиске значений.

# %%
#загружаем, устанавливаем индекс и сортируем по индексу
states_df.set_index(keys="Abbreviation", inplace=True)
states_df.sort_index(inplace=True)
states_df.head()
# Out:
#                    State Capital City  pop_rank       Pop  Growth   Pop2021  \
# Abbreviation
# AK                Alaska       Juneau        48    738023  0.0031    735707
# AL               Alabama   Montgomery        24   5073187  0.0048   5048733
# AR              Arkansas  Little Rock        33   3030646  0.0032   3021085
# AZ               Arizona      Phoenix        14   7303398  0.0105   7227450
# CA            California   Sacramento         1  39995077  0.0057  39766650
#
#                Pop2010  growthSince2010  Percent   density
# Abbreviation
# AK              710231           0.0391   0.0022    1.2933
# AL             4779736           0.0614   0.0151  100.1715
# AR             2915918           0.0393   0.0090   58.2425
# AZ             6392017           0.1426   0.0218   64.2939
# CA            37253956           0.0736   0.1193  256.7424

# %% [markdown]
# ### `.loc[ ]` аксессор (accessor)

# %%
# .loc[ ] - обращаемся по индексу (index label) к строке
states_df.loc["MD"]
# Out:
# State               Maryland
# Capital City       Annapolis
# pop_rank                  18
# Pop                  6257958
# Growth                0.0065
# Pop2021              6217591
# Pop2010              5773552
# growthSince2010       0.0839
# Percent               0.0187
# density              644.685
# Name: MD, dtype: object

# %%
# .loc[ ] - если такого индекса (index label) не существует - получаем KeyError
states_df.loc["AA"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AA'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-7eab3384947a> in <module>
#       1 # .loc[ ] - если такого индекса (index label) не существует - получаем KeyError
# ----> 2 states_df.loc["AA"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AA'

# %%
# слайсинг с .loc[ ]  - END is INCLUSIVE 
states_df.loc["AL":"FL"]
# Out:
#                     State Capital City  pop_rank       Pop  Growth   Pop2021  \
# Abbreviation
# AL                Alabama   Montgomery        24   5073187  0.0048   5048733
# AR               Arkansas  Little Rock        33   3030646  0.0032   3021085
# AZ                Arizona      Phoenix        14   7303398  0.0105   7227450
# CA             California   Sacramento         1  39995077  0.0057  39766650
# CO               Colorado       Denver        21   5922618  0.0127   5848166
# CT            Connecticut     Hartford        29   3612314  0.0009   3609129
# DE               Delaware        Dover        45   1008350  0.0092    999149
# FL                Florida  Tallahassee         3  22085563  0.0125  21811875
#
#                Pop2010  growthSince2010  Percent   density
# Abbreviation
# AL             4779736           0.0614   0.0151  100.1715
# AR             2915918           0.0393   0.0090   58.2425
# AZ             6392017           0.1426   0.0218   64.2939
# CA            37253956           0.0736   0.1193  256.7424
# CO             5029196           0.1776   0.0177   57.1450
# CT             3574097           0.0107   0.0108  746.0376
# DE              897934           0.1230   0.0030  517.3679
# FL            18801310           0.1747   0.0659  411.8520

# %%
# слайсинг с .loc[ ]  - вернем каждую вторую строку в заданном слайсе
states_df.loc["AL":"FL":2]
# Out:
#                  State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AL             Alabama   Montgomery        24  5073187  0.0048  5048733
# AZ             Arizona      Phoenix        14  7303398  0.0105  7227450
# CO            Colorado       Denver        21  5922618  0.0127  5848166
# DE            Delaware        Dover        45  1008350  0.0092   999149
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AL            4779736           0.0614   0.0151  100.1715
# AZ            6392017           0.1426   0.0218   64.2939
# CO            5029196           0.1776   0.0177   57.1450
# DE             897934           0.1230   0.0030  517.3679

# %%
# слайсинг с .loc[ ]  - вернем каждую вторую строку в датасете
states_df.loc[["FL", "WA", "NY"]]
# Out:
#                    State Capital City  pop_rank       Pop  Growth   Pop2021  \
# Abbreviation
# FL               Florida  Tallahassee         3  22085563  0.0125  21811875
# WA            Washington      Olympia        13   7901429  0.0126   7803355
# NY              New York       Albany         4  20365879  0.0041  20283564
#
#                Pop2010  growthSince2010  Percent   density
# Abbreviation
# FL            18801310           0.1747   0.0659  411.8520
# WA             6724540           0.1750   0.0236  118.8971
# NY            19378102           0.0510   0.0607  432.1580

# %%
# сразу несколько значений
states_df.loc[["NY", "NY", "FL", "WA"]]
# Out:
#                    State Capital City  pop_rank       Pop  Growth   Pop2021  \
# Abbreviation
# NY              New York       Albany         4  20365879  0.0041  20283564
# NY              New York       Albany         4  20365879  0.0041  20283564
# FL               Florida  Tallahassee         3  22085563  0.0125  21811875
# WA            Washington      Olympia        13   7901429  0.0126   7803355
#
#                Pop2010  growthSince2010  Percent   density
# Abbreviation
# NY            19378102           0.0510   0.0607  432.1580
# NY            19378102           0.0510   0.0607  432.1580
# FL            18801310           0.1747   0.0659  411.8520
# WA             6724540           0.1750   0.0236  118.8971

# %%
# сразу несколько значений - порядок имеет значение
states_df.loc["NY", ["Capital City", "Pop"]]
# Out:
# Capital City      Albany
# Pop             20365879
# Name: NY, dtype: object

# %%
# только некоторые колонки с указанным индексом
states_df.loc["AL":"FL", ["Capital City", "Pop"]]
# Out:
#              Capital City       Pop
# Abbreviation
# AL             Montgomery   5073187
# AR            Little Rock   3030646
# AZ                Phoenix   7303398
# CA             Sacramento  39995077
# CO                 Denver   5922618
# CT               Hartford   3612314
# DE                  Dover   1008350
# FL            Tallahassee  22085563

# %%
# только некоторые колонки и строки с указанными индексами
states_df.loc["AL":"FL":2, ["Capital City", "Pop"]]
# Out:
#              Capital City      Pop
# Abbreviation
# AL             Montgomery  5073187
# AZ                Phoenix  7303398
# CO                 Denver  5922618
# DE                  Dover  1008350

# %%
# ::_::
states_df.loc[::, ::]
# Out:
#                        State    Capital City  pop_rank       Pop  Growth  \
# Abbreviation
# AK                    Alaska          Juneau        48    738023  0.0031
# AL                   Alabama      Montgomery        24   5073187  0.0048
# AR                  Arkansas     Little Rock        33   3030646  0.0032
# AZ                   Arizona         Phoenix        14   7303398  0.0105
# CA                California      Sacramento         1  39995077  0.0057
# CO                  Colorado          Denver        21   5922618  0.0127
# CT               Connecticut        Hartford        29   3612314  0.0009
# DE                  Delaware           Dover        45   1008350  0.0092
# Abbreviation
# AK              Alaska       Juneau        48   738023  0.0031   735707
# HI              Hawaii     Honolulu        40  1474265  0.0065  1464768
# AR            Arkansas  Little Rock        33  3030646  0.0032  3021085
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AK             710231           0.0391   0.0022    1.2933
# HI            1360301           0.0838   0.0044  229.5290
# AR            2915918           0.0393   0.0090   58.2425

# %%
# сразу несколько значений - IndexError такого значения нет
states_df.iloc[[0, 10, 200]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2109         try:
# -> 2110             return self.obj._take_with_is_copy(key, axis=axis)
#    2111         except IndexError:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1385         if convert:
# -> 1386             indexer = maybe_convert_indices(indexer, n)
#    1387
#
# ~\anaconda3\lib\site-packages\pandas\core\indexers.py in maybe_convert_indices(indices, n)
#     211     if mask.any():
# --> 212         raise IndexError("indices are out-of-bounds")
#     213     return indices
#
# IndexError: indices are out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-d13d3245914b> in <module>
#       1 # сразу несколько значений - IndexError такого значения нет
# ----> 2 states_df.iloc[[0, 10, 200]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2126         # a list of integers
#    2127         elif is_list_like_indexer(key):
# -> 2128             return self._get_list_axis(key, axis=axis)
#    2129
#    2130         # a single integer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2111         except IndexError:
#    2112             # re-raise with different error message
# -> 2113             raise IndexError("positional indexers are out-of-bounds")
#    2114
#    2115     def _getitem_axis(self, key, axis: int):
#
# IndexError: positional indexers are out-of-bounds

# %%
# только некоторые колонки с указанным индексом
states_df.iloc[10, [0,3,5]]
# Out:
# State       Hawaii
# Pop        1474265
# Pop2021    1464768
# Name: HI, dtype: object

# %%
# только некоторые колонки и строки с указанным индексом
states_df.iloc[[1,10], [0,3,5]]
# Out:
#                 State      Pop  Pop2021
# Abbreviation
# AL            Alabama  5073187  5048733
# HI             Hawaii  1474265  1464768

# %%
# слайсы строк и колонок
states_df.iloc[0:10, 0:5]
# Out:
#                     State Capital City  pop_rank       Pop  Growth
# Abbreviation
# AK                 Alaska       Juneau        48    738023  0.0031
# AL                Alabama   Montgomery        24   5073187  0.0048
# AR               Arkansas  Little Rock        33   3030646  0.0032
# AZ                Arizona      Phoenix        14   7303398  0.0105
# CA             California   Sacramento         1  39995077  0.0057
# CO               Colorado       Denver        21   5922618  0.0127
states_df.loc["NY"]
# Out:
# State              New York
# Capital City         Almaty
# pop_rank                  4
# Pop                     200
# Growth                  200
# Pop2021                 200
# Pop2010                 200
# growthSince2010       0.051
# Percent              0.0607
# density             432.158
# Name: NY, dtype: object

# %%
#меняем значения у некоторых строк
lessthan1mln = states_df["Pop"] <= 1000000
states_df[lessthan1mln]
# Out:
#                      State Capital City  pop_rank     Pop    Growth  Pop2021  \
# Abbreviation
# AK                  Alaska       Almaty        48  738023    0.0031   735707
# ND            North Dakota       Almaty        47  800394    0.0135   789744
# NY                New York       Almaty         4     200  200.0000      200
# SD            South Dakota       Almaty        46  901165    0.0081   893916
# VT                 Vermont       Almaty        49  646545    0.0027   644811
# WY                 Wyoming       Almaty        50  579495    0.0023   578173
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AK             710231           0.0391   0.0022    1.2933
# ND             672591           0.1900   0.0024   11.5997
# NY                200           0.0510   0.0607  432.1580
# SD             814180           0.1068   0.0027   11.8870
# VT             625741           0.0332   0.0019   70.1470
# WY             563626           0.0282   0.0017    5.9685

# %%
#меняем значения у некоторых строк - без loc не сработает
states_df[lessthan1mln]["Pop"] = 1000000
# Out:
# C:\Users\77785\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#меняем значения у некоторых строк c loc
states_df.loc[lessthan1mln, "Pop"]
# Out:
# Abbreviation
# AK    738023
# ND    800394
# NY       200
# SD    901165
# VT    646545
# WY    579495
# Name: Pop, dtype: int64

# %%
#меняем значения у некоторых строк c loc
states_df.loc[lessthan1mln, "Pop"] = 1000000

# %%
states_df.loc[lessthan1mln, "Pop"]
# Out:
# Abbreviation
# AK    1000000
# ND    1000000
# NY    1000000
# SD    1000000
# VT    1000000
# WY    1000000
# Name: Pop, dtype: int64

# %% [markdown]
# ### загружаем датафрейм

# %%
#загружаем, устанавливаем индекс и сортируем по индексу (best practice)
states_df = pd.read_excel('states.xlsx')
states_df.set_index(keys = "Abbreviation", inplace=True)
states_df.sort_index(inplace=True)
states_df.head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AK             Alaska       Juneau        48   738023  0.0031   735707
# AL            Alabama   Montgomery        24  5073187  0.0048  5048733
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AK             710231           0.0391   0.0022    1.2933
# AL            4779736           0.0614   0.0151  100.1715

# %% [markdown]
# ###  `.drop( )`  метод

# %%
#метод .drop() - удаляем строку по index label
states_df.drop("AK").head(2)
# Out:
#                  State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AL             Alabama   Montgomery        24  5073187  0.0048  5048733
# AR            Arkansas  Little Rock        33  3030646  0.0032  3021085
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AL            4779736           0.0614   0.0151  100.1715
# AR            2915918           0.0393   0.0090   58.2425

# %%
#метод .drop() - удаляем несколько строк по index label
states_df.drop(["AL", "AR"]).head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AK             Alaska       Juneau        48   738023  0.0031   735707
# AZ            Arizona      Phoenix        14  7303398  0.0105  7227450
#
#               Pop2010  growthSince2010  Percent  density
# Abbreviation
# AK             710231           0.0391   0.0022   1.2933
# AZ            6392017           0.1426   0.0218  64.2939

# %%
# метод .drop() - удаляем колонку 
# параметр axis : 0 или 'index' для строк, 1 или 'columns' для колонок
# по умолчанию axis = 0
# inplace = True для того, чтобы удаление было перманентным
states_df.drop("growthSince2010", axis="columns").head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AK             Alaska       Juneau        48   738023  0.0031   735707
# AL            Alabama   Montgomery        24  5073187  0.0048  5048733
#
#               Pop2010  Percent   density
# Abbreviation
# AK             710231   0.0022    1.2933
# AL            4779736   0.0151  100.1715

# %%
# метод .drop() - удаляем несколько колонок
states_df.drop(["growthSince2010", "Growth", "Percent"], axis="columns").head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Pop2021  Pop2010  \
# Abbreviation
# AK             Alaska       Juneau        48   738023   735707   710231
# AL            Alabama   Montgomery        24  5073187  5048733  4779736
#
#                density
# Abbreviation
# AK              1.2933
# AL            100.1715

# %%
states_df.head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AK             Alaska       Juneau        48   738023  0.0031   735707
# AL            Alabama   Montgomery        24  5073187  0.0048  5048733
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AK             710231           0.0391   0.0022    1.2933
# AL            4779736           0.0614   0.0151  100.1715

# %%
# также можно использовать ключевое слово del, тогда inplace = True не нужен 
del states_df["growthSince2010"]
del states_df["Growth"]
del states_df["Percent"]

states_df.head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Pop2021  Pop2010  \
# Abbreviation
# AK             Alaska       Juneau        48   738023   735707   710231
# AL            Alabama   Montgomery        24  5073187  5048733  4779736
#
#                density
# Abbreviation
# AK              1.2933
# AL            100.1715

# %%
states_df.head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Pop2021  Pop2010  \
# Abbreviation
# AK             Alaska       Juneau        48   738023   735707   710231
# AL            Alabama   Montgomery        24  5073187  5048733  4779736
#
#                density
# Abbreviation
# AK              1.2933
# AL            100.1715

# %% [markdown]
# ###  `.nsmallest( )` и `nlargest( )` методы

# %%
#метод .sort_values() чтобы найти штат с самым большим населением
states_df.sort_values("Pop", ascending = False).head(3)
# Out:
#                    State Capital City  pop_rank       Pop   Pop2021   Pop2010  \
# Abbreviation
# CA            California   Sacramento         1  39995077  39766650  37253956
# TX                 Texas       Austin         2  29945493  29545499  25145561
# FL               Florida  Tallahassee         3  22085563  21811875  18801310
#
#                density
# Abbreviation
# CA            256.7424
# TX            114.6318
# FL            411.8520

# %%
# .nlargest() метод - даст то же самое, но более эффективно
states_df.nlargest(3, "Pop")
# Out:
#                    State Capital City  pop_rank       Pop   Pop2021   Pop2010  \
# Abbreviation
# CA            California   Sacramento         1  39995077  39766650  37253956
# TX                 Texas       Austin         2  29945493  29545499  25145561
# FL               Florida  Tallahassee         3  22085563  21811875  18801310
#
#                density
# Abbreviation
# CA            256.7424
# TX            114.6318
# FL            411.8520

# %%
#метод .sort_values() чтобы найти штат с самым маленьким населением
states_df.sort_values("Pop", ascending = True).head(3)
# Out:
#                 State Capital City  pop_rank     Pop  Growth  Pop2021  \
# Abbreviation
# WY            Wyoming     Cheyenne        50  579495  0.0023   578173
# VT            Vermont   Montpelier        49  646545  0.0027   644811
# AK             Alaska       Juneau        48  738023  0.0031   735707
#
#               Pop2010  growthSince2010  Percent  density
# Abbreviation
# WY             563626           0.0282   0.0017   5.9685
# VT             625741           0.0332   0.0019  70.1470
# AK             710231           0.0391   0.0022   1.2933

# %%
# .nsmallest() метод - даст то же самое, но более эффективно
states_df.nsmallest(3, "Pop")
# Out:
#                 State Capital City  pop_rank     Pop  Pop2021  Pop2010  \
# Abbreviation
# WY            Wyoming     Cheyenne        50  579495   578173   563626
# VT            Vermont   Montpelier        49  646545   644811   625741
# AK             Alaska       Juneau        48  738023   735707   710231
#
#               density
# Abbreviation
# WY             5.9685
# VT            70.1470
# AK             1.2933

# %%
# способ 2: .nsmallest()
states_df["Pop"].nsmallest(3)
# Out:
# Abbreviation
# WY    579495
# VT    646545
# AK    738023
# Name: Pop, dtype: int64

# %%
# способ 2: .nlargest()
states_df["Pop"].nlargest(3)
# Out:
# Abbreviation
# CA    39995077
# TX    29945493
# FL    22085563
# Name: Pop, dtype: int64

# %% [markdown]
# ### `.where()` метод - заменяет значения на NaN, если условие не выполнено (False), возвращает значения, если условие выполнено (True)

# %%
# штаты с населением больше X
big_states = states_df["Pop"] >= 22085563
states_df[big_states]
# Out:
#                    State Capital City  pop_rank       Pop   Pop2021   Pop2010  \
# Abbreviation
# CA            California   Sacramento         1  39995077  39766650  37253956
# FL               Florida  Tallahassee         3  22085563  21811875  18801310
# TX                 Texas       Austin         2  29945493  29545499  25145561
#
#                density
# Abbreviation
# CA            256.7424
# FL            411.8520
# TX            114.6318

# %%
# метод .where() штаты с населением больше X
# штаты с населением больше X
big_states = states_df["Pop"] >= 22085563
states_df.where(big_states)
# Out:
#                    State Capital City  pop_rank         Pop     Pop2021  \
# Abbreviation
# AK                   NaN          NaN       NaN         NaN         NaN
# AL                   NaN          NaN       NaN         NaN         NaN
# AR                   NaN          NaN       NaN         NaN         NaN
# AZ                   NaN          NaN       NaN         NaN         NaN
# CA            California   Sacramento       1.0  39995077.0  39766650.0
# CO                   NaN          NaN       NaN         NaN         NaN
# CT                   NaN          NaN       NaN         NaN         NaN
# DE                   NaN          NaN       NaN         NaN         NaN
# FL               Florida  Tallahassee       3.0  22085563.0  21811875.0
# GA                   NaN          NaN       NaN         NaN         NaN
# HI                   NaN          NaN       NaN         NaN         NaN
# IA                   NaN          NaN       NaN         NaN         NaN
# ID                   NaN          NaN       NaN         NaN         NaN
# IL                   NaN          NaN       NaN         NaN         NaN
# IN                   NaN          NaN       NaN         NaN         NaN
# WI                   NaN       NaN
# WV                   NaN       NaN
# WY                   NaN       NaN

# %%
# метод .where() штаты с плотностью больше X
dense_states = states_df["density"] >= 200
states_df.where(dense_states)
# Out:
#                        State Capital City  pop_rank         Pop     Pop2021  \
# Abbreviation
# AK                       NaN          NaN       NaN         NaN         NaN
# AL                       NaN          NaN       NaN         NaN         NaN
# AR                       NaN          NaN       NaN         NaN         NaN
# AZ                       NaN          NaN       NaN         NaN         NaN
# CA                California   Sacramento       1.0  39995077.0  39766650.0
# CO                       NaN          NaN       NaN         NaN         NaN
# CT               Connecticut     Hartford      29.0   3612314.0   3609129.0
# DE                  Delaware        Dover      45.0   1008350.0    999149.0
# FL                   Florida  Tallahassee       3.0  22085563.0  21811875.0
# GA                       NaN          NaN       NaN         NaN         NaN
# HI                    Hawaii     Honolulu      40.0   1474265.0   1464768.0
# IA                       NaN          NaN       NaN         NaN         NaN
# ID                       NaN          NaN       NaN         NaN         NaN
# IL                  Illinois  Springfield       6.0  12808884.0  12810696.0
# IN                       NaN          NaN       NaN         NaN         NaN
# KS                       NaN          NaN       NaN         NaN         NaN
# KY                       NaN          NaN       NaN         NaN         NaN
# LA                       NaN          NaN       NaN         NaN         NaN
# MA             Massachusetts       Boston      15.0   7126375.0   7078146.0
# MD                  Maryland    Annapolis      18.0   6257958.0   6217591.0
# ME                       NaN          NaN       NaN         NaN         NaN
# MI                       NaN          NaN       NaN         NaN         NaN
# MN                       NaN          NaN       NaN         NaN         NaN
# MO                       NaN          NaN       NaN         NaN         NaN
# MS                       NaN          NaN       NaN         NaN         NaN
# MT                       NaN          NaN       NaN         NaN         NaN
# NC            North Carolina      Raleigh       9.0  10620168.0  10529778.0
# ND                       NaN          NaN       NaN         NaN         NaN
# NE                       NaN          NaN       NaN         NaN         NaN
# NH                       NaN          NaN       NaN         NaN         NaN
# NJ                New Jersey      Trenton      11.0   9388414.0   9338704.0
# NM                       NaN          NaN       NaN         NaN         NaN
# NV                       NaN          NaN       NaN         NaN         NaN
# NY                  New York       Albany       4.0  20365879.0  20283564.0
# OH                      Ohio     Columbus       7.0  11852036.0  11825742.0
# OK                       NaN          NaN       NaN         NaN         NaN
# OR                       NaN          NaN       NaN         NaN         NaN
# PA              Pennsylvania   Harrisburg       5.0  13062764.0  13032732.0
# RI              Rhode Island   Providence      43.0   1106341.0   1101860.0
# SC                       NaN          NaN       NaN         NaN         NaN
# SD                       NaN          NaN       NaN         NaN         NaN
# TN                       NaN          NaN       NaN         NaN         NaN
# TX                       NaN          NaN       NaN         NaN         NaN
# UT                       NaN          NaN       NaN         NaN         NaN
# VA                  Virginia     Richmond      12.0   8757467.0   8694430.0
# VT                       NaN          NaN       NaN         NaN         NaN
# WA                       NaN          NaN       NaN         NaN         NaN
# WI                       NaN          NaN       NaN         NaN         NaN
# WV                       NaN          NaN       NaN         NaN         NaN
# WY                       NaN          NaN       NaN         NaN         NaN
#
#                  Pop2010    density
# Abbreviation
# AK                   NaN        NaN
# AL                   NaN        NaN
# AR                   NaN        NaN
# AZ                   NaN        NaN
# CA            37253956.0   256.7424
# CO                   NaN        NaN
# CT             3574097.0   746.0376
# DE              897934.0   517.3679
# FL            18801310.0   411.8520
# GA                   NaN        NaN
# HI             1360301.0   229.5290
# IA                   NaN        NaN
# ID                   NaN        NaN
# IL            12830632.0   230.7117
# IN                   NaN        NaN
# KS                   NaN        NaN
# KY                   NaN        NaN
# LA                   NaN        NaN
# MA             6547629.0   913.6378
# MD             5773552.0   644.6851
# ME                   NaN        NaN
# MI                   NaN        NaN
# MN                   NaN        NaN
# MO                   NaN        NaN
# MS                   NaN        NaN
# MT                   NaN        NaN
# NC             9535483.0   218.4411
# ND                   NaN        NaN
# NE                   NaN        NaN
# NH                   NaN        NaN
# NJ             8791894.0  1276.6405
# NM                   NaN        NaN
# NV                   NaN        NaN
# NY            19378102.0   432.1580
# OH            11536504.0   290.0574
# OK                   NaN        NaN
# OR                   NaN        NaN
# PA            12702379.0   291.9510
# RI             1052567.0  1069.9623
# SC                   NaN        NaN
# SD                   NaN        NaN
# TN                   NaN        NaN
# TX                   NaN        NaN
# UT                   NaN        NaN
# VA             8001024.0   221.7642
# VT                   NaN        NaN
# WA                   NaN        NaN
# WI                   NaN        NaN
# WV                   NaN        NaN
# WY                   NaN        NaN

# %%
# метод .where() штаты с населением больше X и плотностью больше X
states_df.where(dense_states & big_states)
# Out:
#                    State Capital City  pop_rank         Pop     Pop2021  \
# Abbreviation
# AK                   NaN          NaN       NaN         NaN         NaN
# AL                   NaN          NaN       NaN         NaN         NaN
# AR                   NaN          NaN       NaN         NaN         NaN
# AZ                   NaN          NaN       NaN         NaN         NaN
# CA            California   Sacramento       1.0  39995077.0  39766650.0
# CO                   NaN          NaN       NaN         NaN         NaN
# CT                   NaN          NaN       NaN         NaN         NaN
# DE                   NaN          NaN       NaN         NaN         NaN
# FL               Florida  Tallahassee       3.0  22085563.0  21811875.0
# GA                   NaN          NaN       NaN         NaN         NaN
# HI                   NaN          NaN       NaN         NaN         NaN
# IA                   NaN          NaN       NaN         NaN         NaN
# ID                   NaN          NaN       NaN         NaN         NaN
# IL                   NaN          NaN       NaN         NaN         NaN
# IN                   NaN          NaN       NaN         NaN         NaN
# KS                   NaN          NaN       NaN         NaN         NaN
# KY                   NaN          NaN       NaN         NaN         NaN
# LA                   NaN          NaN       NaN         NaN         NaN
# MA                   NaN          NaN       NaN         NaN         NaN
# MD                   NaN          NaN       NaN         NaN         NaN
# ME                   NaN          NaN       NaN         NaN         NaN
# MI                   NaN          NaN       NaN         NaN         NaN
# MN                   NaN          NaN       NaN         NaN         NaN
# MO                   NaN          NaN       NaN         NaN         NaN
# MS                   NaN          NaN       NaN         NaN         NaN
# MT                   NaN          NaN       NaN         NaN         NaN
# NC                   NaN          NaN       NaN         NaN         NaN
# ND                   NaN          NaN       NaN         NaN         NaN
# NE                   NaN          NaN       NaN         NaN         NaN
# NH                   NaN          NaN       NaN         NaN         NaN
# NJ                   NaN          NaN       NaN         NaN         NaN
# NM                   NaN          NaN       NaN         NaN         NaN
# NV                   NaN          NaN       NaN         NaN         NaN
# NY                   NaN          NaN       NaN         NaN         NaN
# OH                   NaN          NaN       NaN         NaN         NaN
# OK                   NaN          NaN       NaN         NaN         NaN
# OR                   NaN          NaN       NaN         NaN         NaN
# PA                   NaN          NaN       NaN         NaN         NaN
# RI                   NaN          NaN       NaN         NaN         NaN
# SC                   NaN          NaN       NaN         NaN         NaN
# SD                   NaN          NaN       NaN         NaN         NaN
# TN                   NaN          NaN       NaN         NaN         NaN
# TX                   NaN          NaN       NaN         NaN         NaN
# UT                   NaN          NaN       NaN         NaN         NaN
# VA                   NaN          NaN       NaN         NaN         NaN
# VT                   NaN          NaN       NaN         NaN         NaN
# WA                   NaN          NaN       NaN         NaN         NaN
# WI                   NaN          NaN       NaN         NaN         NaN
# WV                   NaN          NaN       NaN         NaN         NaN
# WY                   NaN          NaN       NaN         NaN         NaN
#
#                  Pop2010   density
# Abbreviation
# AK                   NaN       NaN
# AL                   NaN       NaN
# AR                   NaN       NaN
# AZ                   NaN       NaN
# CA            37253956.0  256.7424
# CO                   NaN       NaN
# CT                   NaN       NaN
# DE                   NaN       NaN
# FL            18801310.0  411.8520
# GA                   NaN       NaN
# HI                   NaN       NaN
# IA                   NaN       NaN
# ID                   NaN       NaN
# IL                   NaN       NaN
# IN                   NaN       NaN
# KS                   NaN       NaN
# KY                   NaN       NaN
# LA                   NaN       NaN
# MA                   NaN       NaN
# MD                   NaN       NaN
# ME                   NaN       NaN
# MI                   NaN       NaN
# MN                   NaN       NaN
# MO                   NaN       NaN
# MS                   NaN       NaN
# MT                   NaN       NaN
# NC                   NaN       NaN
# ND                   NaN       NaN
# NE                   NaN       NaN
# NH                   NaN       NaN
# NJ                   NaN       NaN
# NM                   NaN       NaN
# NV                   NaN       NaN
# NY                   NaN       NaN
# OH                   NaN       NaN
# OK                   NaN       NaN
# OR                   NaN       NaN
# PA                   NaN       NaN
# RI                   NaN       NaN
# SC                   NaN       NaN
# SD                   NaN       NaN
# TN                   NaN       NaN
# TX                   NaN       NaN
# UT                   NaN       NaN
# VA                   NaN       NaN
# VT                   NaN       NaN
# WA                   NaN       NaN
# WI                   NaN       NaN
# WV                   NaN       NaN
# WY                   NaN       NaN

# %% [markdown]
# ### `.query()` метод

# %%
# .query() метод - будьте внимательны к кавычкам
# Pop >= 22085563
states_df.query("Pop >=22085563")
# Out:
#                    State Capital City  pop_rank       Pop   Pop2021   Pop2010  \
# Abbreviation
# CA            California   Sacramento         1  39995077  39766650  37253956
# FL               Florida  Tallahassee         3  22085563  21811875  18801310
# TX                 Texas       Austin         2  29945493  29545499  25145561
#
#                density
# Abbreviation
# CA            256.7424
# FL            411.8520
# TX            114.6318

# %%
# .query() метод - будьте внимательны к кавычкам
# пустота если нет таких данных
# Pop >= 39995078
states_df.query("Pop >=39995078")
# Out:
# Empty DataFrame
# Columns: [State, Capital City, pop_rank, Pop, Pop2021, Pop2010, density]
# VA                  Virginia        Richmond        12   8757467   8694430
# VT                   Vermont      Montpelier        49    646545    644811
# WA                Washington         Olympia        13   7901429   7803355
# WI                 Wisconsin         Madison        20   5935064   5914391
# WV             West Virginia      Charleston        39   1781860   1787788
# WY                   Wyoming        Cheyenne        50    579495    578173
#
#                Pop2010    density
# Abbreviation
# AK              710231     1.2933
# AL             4779736   100.1715
# AR             2915918    58.2425
# AZ             6392017    64.2939
# CO             5029196    57.1450
# CT             3574097   746.0376
# DE              897934   517.3679
# GA             9687653   189.8138
# HI             1360301   229.5290
# IA             3046355    57.6324
# ID             1567582    22.9107
# IL            12830632   230.7117
# IN             6483802   191.0868
# KS             2853118    36.1408
# KY             4339367   114.9554
# LA             4533372   108.3842
# MA             6547629   913.6378
# MD             5773552   644.6851
# ME             1328361    44.3912
# MI             9883640   178.9220
# MN             5303925    72.6765
# MO             5988927    90.0194
# MS             2967297    63.0837
# MT              989415     7.5796
# NC             9535483   218.4411
# ND              672591    11.5997
# NE             1826341    25.8843
# NH             1316470   155.2263
# NJ             8791894  1276.6405
# NM             2059179    17.5534
# NV             2700551    29.0162
# NY            19378102   432.1580
# OH            11536504   290.0574
# OK             3751351    58.3272
# OR             3831074    44.9899
# PA            12702379   291.9510
# RI             1052567  1069.9623
# SC             4625364   173.5484
# SD              814180    11.8870
# TN             6346105   170.3356
# TX            25145561   114.6318
# UT             2763885    41.0510
# VA             8001024   221.7642
# VT              625741    70.1470
# WA             6724540   118.8971
# WI             5686986   109.5879
# WV             1852994    74.1268
# WY              563626     5.9685

# %%
# .query() метод - будьте внимательны к кавычкам
# 'State in ["California","Florida"] and density > 400'
states_df.query('State not in ["California","Florida"] and density > 400')
# Out:
#                       State Capital City  pop_rank       Pop   Pop2021  \
# Abbreviation
# CT              Connecticut     Hartford        29   3612314   3609129
# DE                 Delaware        Dover        45   1008350    999149
# MA            Massachusetts       Boston        15   7126375   7078146
# MD                 Maryland    Annapolis        18   6257958   6217591
# NJ               New Jersey      Trenton        11   9388414   9338704
# NY                 New York       Albany         4  20365879  20283564
# RI             Rhode Island   Providence        43   1106341   1101860
#
#                Pop2010    density
# Abbreviation
# CT             3574097   746.0376
# DE              897934   517.3679
# MA             6547629   913.6378
# MD             5773552   644.6851
# NJ             8791894  1276.6405
# NY            19378102   432.1580
# RI             1052567  1069.9623

# %% [markdown]
# ### `.copy()` метод

# %%
#так не работает
lessthan1mln = states_df["Pop"] <= 1000000
states_df[lessthan1mln]["Pop"] = 1000000
# Out:
# C:\Users\77785\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
states_df.sort_values("Pop").head(3)
# Out:
#                 State Capital City  pop_rank     Pop  Pop2021  Pop2010  \
# Abbreviation
# WY            Wyoming     Cheyenne        50  579495   578173   563626
# VT            Vermont   Montpelier        49  646545   644811   625741
# AK             Alaska       Juneau        48  738023   735707   710231
#
#               density
# Abbreviation
# WY             5.9685
# VT            70.1470
# AK             1.2933

# %%
# а вот так выдаст ту же ошибку
Pops = states_df["Pop"]
Pops.head(3)
# Out:
# Abbreviation
# AK     738023
# AL    5073187
# AR    3030646
# Name: Pop, dtype: int64

# %%
#но сработает, даже без inplace=True
Pops["AK"] = 1000000
# Out:
# C:\Users\77785\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Pops.head(3)
# Out:
# Abbreviation
# AK    1000000
# AL    5073187
# AR    3030646
# Name: Pop, dtype: int64

# %%
states_df.sort_values("Pop").head(5)
# Out:
#                      State Capital City  pop_rank      Pop  Pop2021  Pop2010  \
# Abbreviation
# WY                 Wyoming     Cheyenne        50   579495   578173   563626
# VT                 Vermont   Montpelier        49   646545   644811   625741
# ND            North Dakota     Bismarck        47   800394   789744   672591
# SD            South Dakota       Pierre        46   901165   893916   814180
# AK                  Alaska       Juneau        48  1000000   735707   710231
#
#               density
# Abbreviation
# WY             5.9685
# VT            70.1470
# ND            11.5997
# SD            11.8870
# AK             1.2933

# %%
# При задании значений в объекте pandas необходимо следить за тем, 
# чтобы избежать так называемого цепного индексирования.
# Решение? .copy()

# %%
#загружаем, устанавливаем индекс и сортируем по индексу (best practice)
states_df = pd.read_excel('states.xlsx')
states_df.set_index(keys = "Abbreviation", inplace=True)
states_df.sort_index(inplace=True)
states_df.head(2)
# Out:
#                 State Capital City  pop_rank      Pop  Growth  Pop2021  \
# Abbreviation
# AK             Alaska       Juneau        48   738023  0.0031   735707
# AL            Alabama   Montgomery        24  5073187  0.0048  5048733
#
#               Pop2010  growthSince2010  Percent   density
# Abbreviation
# AK             710231           0.0391   0.0022    1.2933
# AL            4779736           0.0614   0.0151  100.1715

# %%
Pops = states_df["Pop"].copy()
Pops.head(3)
# Out:
# Abbreviation
# AK     738023
# AL    5073187
# AR    3030646
# Name: Pop, dtype: int64

# %%
Pops["AK"] = 1000000
Pops.head(3)
# Out:
# Abbreviation
# AK    1000000
# AL    5073187
# AR    3030646
# Name: Pop, dtype: int64

# %%
states_df.query('State=="Alaska"')
# Out:
#                State Capital City  pop_rank     Pop  Growth  Pop2021  Pop2010  \
# Abbreviation
# AK            Alaska       Juneau        48  738023  0.0031   735707   710231
#
#               growthSince2010  Percent  density
# Abbreviation
# AK                     0.0391   0.0022   1.2933

# %% [markdown]
# ### загружаем датафрейм

# %%
#загружаем датафрейм
st_df = pd.read_excel("StudentsPerformance9.xlsx")
st_df.head()
# Out:
#    ID  gender race/ethnicity parental level of education            lunch  \
# 0   1  female        group B           bachelor's degree       standard
# 1   2  female        group C                some college       standard
# 2   3  female        group B             master's degree       standard
# 3   4    male        group A          associate's degree   free/reduced
# 4   5    male        group C                some college       standard
#
#   test preparation course math score reading score writing score
# 0                    none        72%           72%           74%
# 1               completed        69%           90%           88%
# 2                    none        90%           95%           93%
# 3                    none        47%           57%           44%
# 4                    none        76%           78%           75%

# %%
# .info()
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           1072 non-null   int64
#  1   gender                       1072 non-null   object
#  2   race/ethnicity               1072 non-null   object
#  3   parental level of education  1072 non-null   object
#  4   lunch                        1072 non-null   object
#  5   test preparation course      1072 non-null   object
#  6   math score                   1072 non-null   object
#  7   reading score                1072 non-null   object
#  8   writing score                1072 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 75.5+ KB

# %%
#метод .astype("category") для оптимизации
st_df["gender"] = st_df["gender"].astype("category")
st_df["race/ethnicity"] = st_df["race/ethnicity"].astype("category")
st_df["parental level of education"] = st_df["parental level of education"].astype("category")
st_df["lunch"] = st_df["lunch"].astype("category")
st_df["test preparation course"] = st_df["test preparation course"].astype("category")

# %%
# .info()
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           1072 non-null   int64
#  1   gender                       1072 non-null   category
#  2   race/ethnicity               1072 non-null   category
#  3   parental level of education  1072 non-null   category
#  4   lunch                        1072 non-null   category
#  5   test preparation course      1072 non-null   category
#  6   math score                   1072 non-null   object
#  7   reading score                1072 non-null   object
#  8   writing score                1072 non-null   object
# dtypes: category(5), int64(1), object(3)
# memory usage: 39.5+ KB

# %% [markdown]
# ###  методы для работы с текстом

# %%
#буквы в строчные
"COMPLETED".lower()
# Out:
# 'completed'

# %%
#буквы в ЗАГЛАВНЫЕ
"completed".upper()
# Out:
# 'COMPLETED'

# %%
#Каждое Слово С Большой Буквы
"bachelor's degree".title()
# Out:
# "Bachelor'S Degree"

# %%
# применить напрямую к колонке датафрейма не получится
st_df["gender"].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-3fed566c393b> in <module>
#       1 # применить напрямую к колонке датафрейма не получится
# ----> 2 st_df["gender"].upper()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
# нужно использовать .str перед методом
st_df["gender"].str.upper()
# Out:
# 0       FEMALE
# 1       FEMALE
# 2       FEMALE
# 3         MALE
# 4         MALE
#          ...
# 1067    FEMALE
# 1068    FEMALE
# 1069    FEMALE
# 1070    FEMALE
# 1071    FEMALE
# Name: gender, Length: 1072, dtype: object

# %%
# .str.len() подсчитать количество символов
st_df["gender"].str.len()
# Out:
# 0       6
# 1       6
# 2       6
# 3       4
# 4       4
#        ..
# 1067    6
# 1068    6
# 1069    6
# 1070    6
# 1071    6
# Name: gender, Length: 1072, dtype: int64

# %% [markdown]
# ###  `.replace()` метод

# %%
# .replace() заменяет значение в строке
"completed".replace("c", "C")
# Out:
# 'Completed'

# %%
# нужно использовать .str перед методом чтобы применить к колонке датафрейма
st_df["race/ethnicity"].str.replace(" ", "_")
# Out:
# 0       group_B
# 1       group_C
# 2       group_B
# 3       group_A
# 4       group_C
#          ...
# 1067    group_D
# 1068    group_D
# 1069    group_E
# 1070    group_D
# 1071    group_D
# Name: race/ethnicity, Length: 1072, dtype: object

# %%
len("standard")
# Out:
# 8

# %%
st_df["lunch"].str.len()
# Out:
# 0       11
# 1       11
# 2       11
# 3       15
# 4       11
#         ..
# 1067    11
# 1068    11
# 1069    11
# 1070    15
# 1071    11
# Name: lunch, Length: 1072, dtype: int64

# %%
#заменяем пробелы на пустоту
st_df["lunch"] = st_df["lunch"].replace(" ", "")

# %%
#вуаля!
st_df["lunch"].str.len()
# Out:
# 0       11
# 1       11
# 2       11
# 3       15
# 4       11
#         ..
# 1067    11
# 1068    11
# 1069    11
# 1070    15
# 1071    11
# Name: lunch, Length: 1072, dtype: int64

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           1072 non-null   int64
#  1   gender                       1072 non-null   category
#  2   race/ethnicity               1072 non-null   category
#  3   parental level of education  1072 non-null   category
#  4   lunch                        1072 non-null   category
#  5   test preparation course      1072 non-null   category
#  6   math score                   1072 non-null   object
#  7   reading score                1072 non-null   object
#  8   writing score                1072 non-null   object
# dtypes: category(5), int64(1), object(3)
# memory usage: 39.5+ KB

# %%
st_df['lunch'] = st_df['lunch'].astype('category')

# %%
st_df.head()
# Out:
#    ID  gender race/ethnicity parental level of education            lunch  \
# 0   1  female        group B           bachelor's degree       standard
# 1   2  female        group C                some college       standard
# 2   3  female        group B             master's degree       standard
# 3   4    male        group A          associate's degree   free/reduced
# 4   5    male        group C                some college       standard
#
#   test preparation course math score reading score writing score
# 0                    none        72%           72%           74%
# 1               completed        69%           90%           88%
# 2                    none        90%           95%           93%
# 3                    none        47%           57%           44%
# 4                    none        76%           78%           75%

# %%
#удаляем знак % и конвертируем в integer
st_df["math score"] = st_df["math score"].str.replace("%", "").astype(int)
st_df["reading score"] = st_df["reading score"].str.replace("%", "").astype(int)
st_df["writing score"] = st_df["writing score"].str.replace("%", "").astype(int)

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           1072 non-null   int64
#  1   gender                       1072 non-null   category
#  2   race/ethnicity               1072 non-null   category
#  3   parental level of education  1072 non-null   category
#  4   lunch                        1072 non-null   category
#  5   test preparation course      1072 non-null   category
#  6   math score                   1072 non-null   int32
#  7   reading score                1072 non-null   int32
#  8   writing score                1072 non-null   int32
# dtypes: category(5), int32(3), int64(1)
# memory usage: 27.0 KB

# %% [markdown]
# ### `.contains()` метод

# %%
# .contains() возвращает True/False если указанное значение есть в содержании
st_df["gender"].str.contains("f")
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1067     True
# 1068     True
# 1069     True
# 1070     True
# 1071     True
# Name: gender, Length: 1072, dtype: bool

# %%
fem = st_df["gender"].str.contains("f")
st_df[fem].head(2)
# Out:
#    ID  gender race/ethnicity parental level of education        lunch  \
# 0   1  female        group B           bachelor's degree   standard
# 1   2  female        group C                some college   standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %% [markdown]
# ### `.startswith()` метод

# %%
# .startswith() возвращает True/False если строка начинается с ...
males = st_df["gender"].str.startswith("male")
st_df[males].head(2)
# Out:
#    ID gender race/ethnicity parental level of education            lunch  \
# 3   4   male        group A          associate's degree   free/reduced
# 4   5   male        group C                some college       standard
#
#   test preparation course  math score  reading score  writing score
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### `.endswith()` метод

# %%
# .endswith() возвращает True/False если строка заканчивается на ...
# groupB = st_df["race/ethnicity"].str.endswith("b") # не сработает
groupB = st_df["race/ethnicity"].str.endswith("B")
st_df[groupB].head(2)
# Out:
#    ID  gender race/ethnicity parental level of education        lunch  \
# 0   1  female        group B           bachelor's degree   standard
# 2   3  female        group B             master's degree   standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 2                    none          90             95             93

# %%
# но если добавить .lower() то сработает
# при method chaining - str нужно применить дважды!
groupB = st_df["race/ethnicity"].str.lower().str.endswith("b")
st_df[groupB].head(2)
# Out:
#    ID  gender race/ethnicity parental level of education        lunch  \
# 0   1  female        group B           bachelor's degree   standard
# 2   3  female        group B             master's degree   standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 2                    none          90             95             93

# %% [markdown]
# ### `strip( )`, `lstrip( )` и  `rstrip()` методы

# %%
#загружаем датафрейм
st_df = pd.read_excel("StudentsPerformance9.xlsx")
#конвертируем в категории
st_df['gender'] = st_df['gender'].astype('category')
st_df['race/ethnicity'] = st_df['race/ethnicity'].astype('category')
st_df['parental level of education'] = st_df['parental level of education'].astype('category')
st_df['lunch'] = st_df['lunch'].astype('category')
st_df['test preparation course'] = st_df['test preparation course'].astype('category')
#убираем %, конвертируем в int
st_df["math score"] = st_df["math score"].str.replace("%", "").astype(int)
st_df["reading score"] = st_df["reading score"].str.replace("%", "").astype(int)
st_df["writing score"] = st_df["writing score"].str.replace("%", "").astype(int)

st_df.head()
# Out:
#    ID  gender race/ethnicity parental level of education            lunch  \
# 0   1  female        group B           bachelor's degree       standard
# 1   2  female        group C                some college       standard
# 2   3  female        group B             master's degree       standard
# 3   4    male        group A          associate's degree   free/reduced
# 4   5    male        group C                some college       standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           1072 non-null   int64
#  1   gender                       1072 non-null   category
#  2   race/ethnicity               1072 non-null   category
#  3   parental level of education  1072 non-null   category
#  4   lunch                        1072 non-null   category
#  5   test preparation course      1072 non-null   category
#  6   math score                   1072 non-null   int32
#  7   reading score                1072 non-null   int32
#  8   writing score                1072 non-null   int32
# dtypes: category(5), int32(3), int64(1)
# memory usage: 27.0 KB

# %%
#пробелы в колонке lunch
st_df["lunch"].str.len()
# Out:
# 0       11
# 1       11
# 2       11
# 3       15
# 4       11
#         ..
# 1067    11
# 1068    11
# 1069    11
# 1070    15
# 1071    11
# Name: lunch, Length: 1072, dtype: int64

# %%
# lstrip() удаляет пробелы слева
"  lunch  ".lstrip()
# Out:
# 'lunch  '

# %%
# rstrip() удаляет пробелы справа
"  lunch  ".rstrip()
# Out:
# '  lunch'

# %%
# strip() удаляет пробелы c двух сторон
"  lunch  ".strip()
# Out:
# 'lunch'

# %%
# удаляем пробелы из колонки lunch и перезаписываем
st_df["lunch"] = st_df["lunch"].str.strip()

# %%
# проверяем
st_df["lunch"].str.len()
# Out:
# 0        8
# 1        8
# 2        8
# 3       12
# 4        8
#         ..
# 1067     8
# 1068     8
# 1069     8
# 1070    12
# 1071     8
# Name: lunch, Length: 1072, dtype: int64

# %% [markdown]
# ### string методы для названий колонок

# %%
# атрибут columns вернет список названий колонок
st_df.columns
# Out:
# Index(['ID', 'gender', 'race/ethnicity', 'parental level of education',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
st_df.columns.str.upper()
# Out:
# Index(['ID', 'GENDER', 'RACE/ETHNICITY', 'PARENTAL LEVEL OF EDUCATION',
#        'LUNCH', 'TEST PREPARATION COURSE', 'MATH SCORE', 'READING SCORE',
#        'WRITING SCORE'],
#       dtype='object')

# %%
st_df.columns.str.lower()
# Out:
# Index(['id', 'gender', 'race/ethnicity', 'parental level of education',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
st_df.columns = st_df.columns.str.title()
st_df.columns
# Out:
# Index(['Id', 'Gender', 'Race/Ethnicity', 'Parental_Level_Of_Education',
#        'Lunch', 'Test_Preparation_Course', 'Math_Score', 'Reading_Score',
#        'Writing_Score'],
#       dtype='object')

# %%
st_df.columns = st_df.columns.str.replace("/", "_or_")
st_df.columns
# Out:
# Index(['Id', 'Gender', 'Race_or_Ethnicity', 'Parental_Level_Of_Education',
#        'Lunch', 'Test_Preparation_Course', 'Math_Score', 'Reading_Score',
#        'Writing_Score'],
#       dtype='object')

# %%
st_df.columns = st_df.columns.str.replace(" ", "_")
st_df.columns
# Out:
# Index(['Id', 'Gender', 'Race_or_Ethnicity', 'Parental_Level_Of_Education',
#        'Lunch', 'Test_Preparation_Course', 'Math_Score', 'Reading_Score',
#        'Writing_Score'],
#       dtype='object')

# %% [markdown]
# ### split методы

# %%
#.split() - разбивает строку по разделителю
"Data is booming".split(" ")
# Out:
# ['Data', 'is', 'booming']

# %%
#.split() - разбиваем колонку по разделителю
st_df["Race_or_Ethnicity"].str.split(" ")
# Out:
# 0       [group, B]
# 1       [group, C]
# 2       [group, B]
# 3       [group, A]
# 4       [group, C]
#            ...
# 1067    [group, D]
# 1068    [group, D]
# 1069    [group, E]
# 1070    [group, D]
# 1071    [group, D]
# Name: Race_or_Ethnicity, Length: 1072, dtype: object

# %%
#возвращаем второй элемент методом .get()
st_df["Race_or_Ethnicity"].str.split(" ").str.get(1)
# Out:
# 0       B
# 1       C
# 2       B
# 3       A
# 4       C
#        ..
# 1067    D
# 1068    D
# 1069    E
# 1070    D
# 1071    D
# Name: Race_or_Ethnicity, Length: 1072, dtype: object

# %%
#считаем кол-во
st_df["Race_or_Ethnicity"].str.split(" ").str.get(1).value_counts()
# Out:
# C    338
# D    282
# B    201
# E    152
# A     99
# Name: Race_or_Ethnicity, dtype: int64

# %%
#можно указать, сколько раз строка будет делиться
"Data is booming Python is blooming".split(" ", 1)
# Out:
# ['Data', 'is booming Python is blooming']

# %%
#разделяем колонку на 2 и записываем в датафрейм
st_df[["edu_name", "edu_type"]] = st_df["Parental_Level_Of_Education"].str.split(" ", 1, expand=True)

# %%
st_df.head()
# Out:
#    Id  Gender Race_or_Ethnicity Parental_Level_Of_Education         Lunch  \
# 0   1  female           group B           bachelor's degree      standard
# 1   2  female           group C                some college      standard
# 2   3  female           group B             master's degree      standard
# 3   4    male           group A          associate's degree  free/reduced
# 4   5    male           group C                some college      standard
#
#   Test_Preparation_Course  Math_Score  Reading_Score  Writing_Score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#       edu_name edu_type
# 0   bachelor's   degree
# 1         some  college
# 2     master's   degree
# 3  associate's   degree
# 4         some  college

# %%
#экспортируем датасет
st_df.to_csv("Students_Performance_completed.csv")

# %%
#метод .astype("category") для оптимизации
st_df['Gender'] = st_df['Gender'].astype('category')
st_df['Race_or_Ethnicity'] = st_df['Race_or_Ethnicity'].astype('category')
st_df['Parental_Level_Of_Education'] = st_df['Parental_Level_Of_Education'].astype('category')
st_df['Lunch'] = st_df['Lunch'].astype('category')
st_df['Test_Preparation_Course'] = st_df['Test_Preparation_Course'].astype('category')

#метод .drop() для удаления ненужных колонок
st_df.drop(columns = ["edu_name", "edu_type"], inplace = True)

# %%
# .info()
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           1072 non-null   int64
#  1   Gender                       1072 non-null   category
#  2   Race_or_Ethnicity            1072 non-null   category
#  3   Parental_Level_Of_Education  1072 non-null   category
#  4   Lunch                        1072 non-null   category
#  5   Test_Preparation_Course      1072 non-null   category
#  6   Math_Score                   1072 non-null   int32
#  7   Reading_Score                1072 non-null   int32
#  8   Writing_Score                1072 non-null   int32
# dtypes: category(5), int32(3), int64(1)
# memory usage: 27.0 KB

# %% [markdown]
# ### `.groupby()`

# %%
#группируем строки по RaceorEthnicity
#получаем DataFrameGroupBy object - сгруппированный набор 
#DataFrameGroupBy object - это НЕ датафрейм
EthnicGroups = st_df.groupby("Race_or_Ethnicity")
EthnicGroups

# %%
type(EthnicGroups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
#кол-во групп с помощью .len()
len(EthnicGroups)
# Out:
# 5

# %%
#кол-во групп с помощью .nunique()
st_df["Race_or_Ethnicity"].nunique()
# Out:
# 5

# %%
#размер групп с помощью .size() - сортировка по алфавиту
EthnicGroups.size()
# Out:
# Race_or_Ethnicity
# group A     99
# group B    201
# group C    338
# group D    282
# group E    152
# dtype: int64

# %%
#размер групп с помощью .value_counts() - сортировка по кол-ву
st_df["Race_or_Ethnicity"].value_counts()
# Out:
# group C    338
# group D    282
# group B    201
# group E    152
# group A     99
# Name: Race_or_Ethnicity, dtype: int64

# %%
#максимальные оценки по математике по группам
EthnicGroups["Math_Score"].max()
# Out:
# Race_or_Ethnicity
# group A    100
# group B     97
# group C     98
# group D    100
# group E    100
# Name: Math_Score, dtype: int32

# %%
#минимальные оценки по математике по группам
EthnicGroups["Math_Score"].min()
# Out:
# Race_or_Ethnicity
# group A    28
# group B     8
# group C     0
# group D    26
# group E    30
# Name: Math_Score, dtype: int32

# %%
#средние оценки по математике по группам
EthnicGroups["Math_Score"].mean()
# Out:
# Race_or_Ethnicity
# group A    60.888889
# group B    63.542289
# group C    64.325444
# group D    67.407801
# group E    73.506579
# Name: Math_Score, dtype: float64

# %%
#медианные оценки по математике по группам
EthnicGroups["Math_Score"].median()
# Out:
# Race_or_Ethnicity
# group A    61.0
# group B    63.0
# group C    64.5
# group D    69.0
# group E    74.0
# Name: Math_Score, dtype: float64

# %%
#стандартное отклонение оценки по математике по группам
EthnicGroups["Math_Score"].std()
# Out:
# Race_or_Ethnicity
# group A    14.392380
# group B    15.324472
# group C    14.760823
# group D    13.734921
# group E    15.489794
# Name: Math_Score, dtype: float64

# %%
#статистические метрики оценки по математике по группам
EthnicGroups["Math_Score"].describe()
# Out:
#                    count       mean        std   min    25%   50%   75%    max
# Race_or_Ethnicity
# group A             99.0  60.888889  14.392380  28.0  50.00  61.0  71.0  100.0
# group B            201.0  63.542289  15.324472   8.0  54.00  63.0  74.0   97.0
# group C            338.0  64.325444  14.760823   0.0  55.00  64.5  74.0   98.0
# group D            282.0  67.407801  13.734921  26.0  59.00  69.0  77.0  100.0
# group E            152.0  73.506579  15.489794  30.0  64.75  74.0  85.0  100.0

# %%
# первая строка в каждой группе
EthnicGroups.first()
# Out:
#                    Id  Gender Parental_Level_Of_Education         Lunch  \
# Race_or_Ethnicity
# group A             4    male          associate's degree  free/reduced
# group B             1  female           bachelor's degree      standard
# group C             2  female                some college      standard
# group D             9    male                 high school  free/reduced
# group E            33  female             master's degree  free/reduced
#
#                   Test_Preparation_Course  Math_Score  Reading_Score  \
# Race_or_Ethnicity
# group A                              none          47             57
# group B                              none          72             72
# group C                         completed          69             90
# group D                         completed          64             64
# group E                              none          56             72
#
#                    Writing_Score
# Race_or_Ethnicity
# group A                       44
# group B                       74
# group C                       88
# group D                       67
# group E                       65

# %%
# последняя строка в каждой группе
EthnicGroups.last()
# Out:
#                     Id  Gender Parental_Level_Of_Education         Lunch  \
# Race_or_Ethnicity
# group A            577    male                some college      standard
# group B            579  female                some college  free/reduced
# group C            574  female                 high school  free/reduced
# group D            584  female          associate's degree      standard
# group E            582  female            some high school      standard
#
#                   Test_Preparation_Course  Math_Score  Reading_Score  \
# Race_or_Ethnicity
# group A                         completed          61             51
# group B                         completed          48             56
# group C                         completed          50             66
# group D                         completed          73             75
# group E                              none          77             79
#
#                    Writing_Score
# Race_or_Ethnicity
# group A                       52
# group B                       58
# group C                       64
# group D                       80
# group E                       80

# %%
#индексы (indices!) в каждой группе
EthnicGroups.indices
# Out:
# {'group A': array([   3,   13,   14,   25,   46,   61,   62,   72,   77,   82,   88,
#          112,  129,  143,  150,  151,  170,  228,  250,  296,  300,  305,
#          327,  356,  365,  368,  378,  379,  384,  395,  401,  402,  423,
#          428,  433,  442,  444,  464,  467,  468,  483,  489,  490,  506,
#          511,  539,  546,  571,  575,  576,  586,  589,  591,  597,  614,
#          623,  635,  651,  653,  688,  697,  702,  705,  731,  741,  769,
#          778,  805,  810,  811,  816,  820,  830,  832,  837,  851,  892,
#          902,  911,  936,  943,  960,  966,  972,  974,  983,  985,  988,
#          994, 1011, 1020, 1023, 1033, 1034, 1039, 1050, 1059, 1063, 1064],
#        dtype=int64),
#  'group B': array([   0,    2,    5,    6,    7,    9,   12,   17,   21,   26,   31,
#           39,   42,   43,   45,   65,   68,   75,   80,   81,   94,   96,
#          100,  103,  108,  109,  116,  121,  125,  126,  136,  146,  152,
#          157,  158,  160,  162,  167,  168,  176,  178,  188,  192,  198,
#          199,  203,  208,  209,  215,  218,  219,  221,  224,  232,  238,
# %%
#индексы в каждой группе
EthnicGroups.groups
# Out:
# {'group A': Int64Index([   3,   13,   14,   25,   46,   61,   62,   72,   77,   82,   88,
#               112,  129,  143,  150,  151,  170,  228,  250,  296,  300,  305,
#               327,  356,  365,  368,  378,  379,  384,  395,  401,  402,  423,
#               428,  433,  442,  444,  464,  467,  468,  483,  489,  490,  506,
#               511,  539,  546,  571,  575,  576,  586,  589,  591,  597,  614,
#               623,  635,  651,  653,  688,  697,  702,  705,  731,  741,  769,
#               778,  805,  810,  811,  816,  820,  830,  832,  837,  851,  892,
#               902,  911,  936,  943,  960,  966,  972,  974,  983,  985,  988,
#               994, 1011, 1020, 1023, 1033, 1034, 1039, 1050, 1059, 1063, 1064],
#             dtype='int64'),
#  'group B': Int64Index([   0,    2,    5,    6,    7,    9,   12,   17,   21,   26,
#              ...
#              1005, 1010, 1015, 1016, 1035, 1051, 1053, 1056, 1065, 1066],
#             dtype='int64', length=201),
#  'group C': Int64Index([   1,    4,   10,   15,   16,   18,   19,   23,   27,   28,
#              ...
#              1022, 1026, 1036, 1037, 1042, 1048, 1049, 1052, 1060, 1061],
#             dtype='int64', length=338),
#  'group D': Int64Index([   8,   11,   20,   22,   24,   29,   30,   33,   36,   37,
#              ...
#              1043, 1044, 1046, 1054, 1057, 1058, 1067, 1068, 1070, 1071],
#             dtype='int64', length=282),
#  'group E': Int64Index([  32,   34,   35,   44,   50,   51,   56,   60,   76,   79,
#              ...
#              1025, 1030, 1038, 1040, 1041, 1045, 1047, 1055, 1062, 1069],
#             dtype='int64', length=152)}

# %%
#среднее по всем колонкам
EthnicGroups.mean(numeric_only=True)
# Out:
#                            Id  Math_Score  Reading_Score  Writing_Score
# Race_or_Ethnicity
# group A            519.434343   60.888889      64.070707      62.090909
# group B            474.174129   63.542289      67.592040      65.796020
# group C            488.384615   64.325444      69.260355      67.940828
# group D            506.099291   67.407801      70.425532      70.585106
# group E            519.638158   73.506579      72.684211      70.914474

# %% [markdown]
# ### `.get_group()`

# %%
#не зная методы groupby, get_group мы бы писали минимум 5 строк кода
# DRY - don't repeat yourself - принцип кодинга
EthnicGroups.get_group("group A")
# Out:
#        Id  Gender Parental_Level_Of_Education         Lunch  \
# 3       4    male          associate's degree  free/reduced
# 13     14    male                some college      standard
# 14     15  female             master's degree      standard
# 25     26    male             master's degree  free/reduced
# 46     47  female          associate's degree      standard
# ...   ...     ...                         ...           ...
# 1039  385  female            some high school  free/reduced
# 1050  396    male                 high school  free/reduced
# 1059  995    male                 high school      standard
# 1063  576    male          associate's degree  free/reduced
# 1064  577    male                some college      standard
#
#      Test_Preparation_Course  Math_Score  Reading_Score  Writing_Score
# 3                       none          47             57             44
# 13                 completed          78             72             70
# 14                      none          50             53             58
# 25                      none          73             74             72
# 46                 completed          55             65             62
# ...                      ...         ...            ...            ...
# 1039                    none          38             43             43
# 1050                    none          48             45             41
# 1059                    none          63             63             62
# 1063               completed          40             55             53
# 1064               completed          61             51             52
#
# [99 rows x 8 columns]
